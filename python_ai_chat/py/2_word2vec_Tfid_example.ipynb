# %% [markdown]
# # word2vec, Tfid example

# %% [markdown]
# # model 1 : TfidVectorizer

# %%
rom sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import numpy

texts = ["This first text talks about houses and dogs",
        "This is about airplanes and airlines",
        "This is about dogs and houses too, but also about trees",
        "Trees and dogs are main characters in this story",
        "This story is about batman and superman fighting each other", 
        "Nothing better than another story talking about airplanes, airlines and birds",
        "Superman defeats batman in the last round"]

# vectorization of the texts
vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(texts)
# used words (axis in our multi-dimensional space)
words = vectorizer.get_feature_names()
print("words", words)


n_clusters=3
number_of_seeds_to_try=10
max_iter = 300
number_of_process=2 # seads are distributed
model = KMeans(n_clusters=n_clusters, max_iter=max_iter, n_init=number_of_seeds_to_try, n_jobs=number_of_process).fit(X)

labels = model.labels_
# indices of preferible words in each cluster
ordered_words = model.cluster_centers_.argsort()[:, ::-1]

print("centers:", model.cluster_centers_)
print("labels", labels)
print("intertia:", model.inertia_)

texts_per_cluster = numpy.zeros(n_clusters)
for i_cluster in range(n_clusters):
    for label in labels:
        if label==i_cluster:
            texts_per_cluster[i_cluster] +=1 

print("Top words per cluster:")
for i_cluster in range(n_clusters):
    print("Cluster:", i_cluster, "texts:", int(texts_per_cluster[i_cluster])),
    for term in ordered_words[i_cluster, :10]:
        print("\t"+words[term])

print("\n")
print("Prediction")

text_to_predict = "Why batman was defeated  by superman so easy?"
Y = vectorizer.transform([text_to_predict])
predicted_cluster = model.predict(Y)[0]
texts_per_cluster[predicted_cluster]+=1

print(text_to_predict)
print("Cluster:", predicted_cluster, "texts:", int(texts_per_cluster[predicted_cluster])),
for term in ordered_words[predicted_cluster, :10]:
print("\t"+words[term])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import numpy

# %%
texts = ["This first text talks about houses and dogs",
        "This is about airplanes and airlines",
        "This is about dogs and houses too, but also about trees",
        "Trees and dogs are main characters in this story",
        "This story is about batman and superman fighting each other", 
        "Nothing better than another story talking about airplanes, airlines and birds",
        "Superman defeats batman in the last round"]

# %%
texts
# Out:
# ['This first text talks about houses and dogs',
#  'This is about airplanes and airlines',
#  'This is about dogs and houses too, but also about trees',
#  'Trees and dogs are main characters in this story',
#  'This story is about batman and superman fighting each other',
#  'Nothing better than another story talking about airplanes, airlines and birds',
#  'Superman defeats batman in the last round']

# %%
# vectorization of the texts
vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(texts)
# used words (axis in our multi-dimensional space)
words = vectorizer.get_feature_names()
print("words", words)
# Out:
# words ['airlines', 'airplanes', 'batman', 'better', 'birds', 'characters', 'defeats', 'dogs', 'fighting', 'houses', 'main', 'round', 'story', 'superman', 'talking', 'talks', 'text', 'trees']

# %%
# vectorization of the texts
vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(texts)
# used words (axis in our multi-dimensional space)
words = vectorizer.get_feature_names()
print("words", words)
# Out:
# words ['airlines', 'airplanes', 'batman', 'better', 'birds', 'characters', 'defeats', 'dogs', 'fighting', 'houses', 'main', 'round', 'story', 'superman', 'talking', 'talks', 'text', 'trees']

# %%
n_clusters=3
number_of_seeds_to_try=10
max_iter = 300
number_of_process=2 # seads are distributed
model = KMeans(n_clusters=n_clusters, max_iter=max_iter, n_init=number_of_seeds_to_try, n_jobs=number_of_process).fit(X)

# %%
labels = model.labels_
# indices of preferible words in each cluster
ordered_words = model.cluster_centers_.argsort()[:, ::-1]

# %%
print("centers:", model.cluster_centers_)
print("labels", labels)
print("intertia:", model.inertia_)
# Out:
# centers: [[0.         0.         0.         0.         0.         0.17338766
#   0.         0.42781557 0.         0.35657892 0.17338766 0.
#   0.12302372 0.         0.         0.18655847 0.18655847 0.34564602]
#  [0.         0.         0.47031955 0.         0.         0.
#   0.27204122 0.         0.29455022 0.         0.         0.27204122
#   0.20899219 0.47031955 0.         0.         0.         0.        ]
#  [0.54140529 0.54140529 0.         0.22630417 0.22630417 0.
#   0.         0.         0.         0.         0.         0.
#   0.16056958 0.         0.22630417 0.         0.         0.        ]]
# labels [0 2 0 0 1 2 1]
# intertia: 2.303425701724866

# %%
texts_per_cluster = numpy.zeros(n_clusters)
for i_cluster in range(n_clusters):
    for label in labels:
        if label==i_cluster:
            texts_per_cluster[i_cluster] +=1

# %%
print("Top words per cluster:")
for i_cluster in range(n_clusters):
    print("Cluster:", i_cluster, "texts:", int(texts_per_cluster[i_cluster])),
    for term in ordered_words[i_cluster, :10]:
        print("\t"+words[term])
# Out:
# Top words per cluster:
# Cluster: 0 texts: 3
# 	dogs
# 	houses
# 	trees
# 	talks
# 	text
# 	characters
# 	main
# 	story
# 	airplanes
# 	batman
# Cluster: 1 texts: 2
# 	batman
# 	superman
# 	fighting
# 	defeats
# 	round
# 	story
# 	airplanes
# 	better
# 	birds
# 	characters
# Cluster: 2 texts: 2
# 	airlines
# 	airplanes
# 	talking
# 	better
# 	birds
# 	story
# 	dogs
# 	batman
# 	characters
# 	defeats

# %%
print("\n")
print("Prediction")
# Out:
# Prediction

# %%
text_to_predict = "Why batman was defeated  by superman so easy?"
Y = vectorizer.transform([text_to_predict])
predicted_cluster = model.predict(Y)[0]
texts_per_cluster[predicted_cluster]+=1

# %%
print(text_to_predict)
print("Cluster:", predicted_cluster, "texts:", int(texts_per_cluster[predicted_cluster])),
for term in ordered_words[predicted_cluster, :10]:
    print("\t"+words[term])
# Out:
# Why batman was defeated  by superman so easy?
# Cluster: 1 texts: 3
# 	batman
# 	superman
# 	fighting
# 	defeats
# 	round
# 	story
# 	airplanes
# 	better
# 	birds
# 	characters

# %% [markdown]
# # model 2 : sentense similarity

# %%
import numpy as np 

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vect = TfidfVectorizer(min_df=1)

# %%
tfidf = vect.fit_transform(["My name is Ankit", 
          "Ankit name is very famous", 
          "Ankit like his name", 
          "India has a lot of beautiful cities"])

# %%
print(tfidf)
# Out:
#   (0, 10)	0.6406554311067799
#   (0, 11)	0.4089220628888078
#   (0, 7)	0.5051001005334584
#   (0, 0)	0.4089220628888078
#   (1, 11)	0.34432085671547236
#   (1, 7)	0.4253047588435995
#   (1, 0)	0.34432085671547236
#   (1, 13)	0.5394451581794177
#   (1, 3)	0.5394451581794177
#   (2, 11)	0.38044393252779135
#   (2, 0)	0.38044393252779135
#   (2, 8)	0.5960389368177127
#   (2, 5)	0.5960389368177127
#   (3, 6)	0.408248290463863
#   (3, 4)	0.408248290463863
#   (3, 9)	0.408248290463863
#   (3, 12)	0.408248290463863
#   (3, 1)	0.408248290463863
#   (3, 2)	0.408248290463863

# %%
print ((tfidf * tfidf.T).A)
# Out:
# [[1.         0.49642227 0.31114384 0.        ]
#  [0.49642227 1.         0.26198956 0.        ]
#  [0.31114384 0.26198956 1.         0.        ]
#  [0.         0.         0.         1.        ]]

# %% [markdown]
# # model3 : sentense similariry 2

# %%
# !conda install gensim
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#   added / updated specs:
#     - gensim
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.11.29         |           py36_0         146 KB
#     botocore-1.12.67           |           py36_0         3.4 MB
#     jmespath-0.9.3             |           py36_0          35 KB
#     s3transfer-0.1.13          |           py36_0          76 KB
#     boto3-1.9.66               |           py36_0         108 KB
#     smart_open-1.7.1           |           py36_0          67 KB
#     conda-4.5.12               |           py36_0         1.0 MB
#     gensim-3.4.0               |   py36h1de35cc_0        21.5 MB
#     ------------------------------------------------------------
#                                            Total:        26.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     boto3:      1.9.66-py36_0
#     botocore:   1.12.67-py36_0
#     gensim:     3.4.0-py36h1de35cc_0
#     jmespath:   0.9.3-py36_0
#     s3transfer: 0.1.13-py36_0
#     smart_open: 1.7.1-py36_0
#
# The following packages will be UPDATED:
#
#     certifi:    2018.10.15-py36_0    --> 2018.11.29-py36_0
#     conda:      4.5.11-py36_0        --> 4.5.12-py36_0
#
# Proceed ([y]/n)?

# %%
from gensim.models import Word2Vec

# %%
import os
os.getcwd()
# Out:
# '/Users/a60029753/Desktop/python_project_self/python_project_1_javis/py'

# %%
os.chdir('/Users/a60029753/Desktop/python_project_self/python_project_1_javis/data')

# %%
os.getcwd()
# Out:
# '/Users/a60029753/Desktop/python_project_self/python_project_1_javis/data'

# %%
os.listdir()
# Out:
# ['2016_filtered_review.txt']

# %%
with open('2016_filtered_review.txt', encoding='utf-8') as f:
    docs = [line.strip().split('\t\t') for line in f]

# %%
docs
# Out:
# [['140693', ' 아니 딴 그렇 비 비탄 총 대체 왜 들 온겨', '7'],
#  ['140693', ' 진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임', '1'],
#  ['140693',
#   ' 역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 실사 했 사람 거르려 그냥 봤 정말 흠잡 없는 최고 좀비 영화 잔인 거 싫어하지 참고 볼 만하 로미 인물 왜 그런 모르',
#   '10'],
#  ['140693', ' 온종일 불편한 피 범벅 일', '6'],
#  ['140693', ' 답답함 극치 움직일 잇으 좀 움직여 어지간히 좀비 봣으 얼 타고 때려 잡 때 되 않냐', '1'],
#  ['140693', ' 중간 중간 루즈 연출 아쉽 마지막 주자 창 대량학살 신 때문 이점 수준', '7'],
#  ['140693',
#   ' 흔한 좀비 영화 흔하지 않은 흔한 우리네 모습 주인공 펼 본격 좀비 액션 사격 영화 당췌 여고생 존재 의미 모르',
#   '7'],
#  ['140693', ' 좀비 캐릭터 역대 듯 일본 스러웠 높이뛰기 좀비 대박 이었 로미 캐릭터 제대로 살리 못 부분 아쉬웠', '8'],
#  ['140693', ' 초반 부산 행보 낫 후반 부산 행 더 낫다 둘 씹 노잼', '5'],
#  ['140693', ' 좀비 영화 라지 너무 무 내용 없자', '3'],
#  ['140693', ' 너무 태연 너무나 태연', '5'],
#  ['140693',
#   ' 새벽 저주 잭 스나이더 레지던트 이블 나 전설 월드 워 아이엠 어 히어로 좀비 영화 종결자 더 이상 말 필요한',
#   '10'],
#  ['140693', ' 무섭 시작하고 허무 하게 끝나는 영화', '7'],
#  ['140693',
#   ' 여자친구 좀비 변했 때 공포영화 같은 기 괴한 장면 가장 인상 이었 뒤 갈 수록 내용 산 간다 총 좀비 학살 하는 장면 너무 길어 지루할 정도 였',
#   '4'],
#  ['140693',
#   ' 일본 영화관 오는 관객 대다수 씹 오덕 하는 그냥 애니 만들어 할 아는 건 고어 애니 이 다인 일본 영화',
#   '1'],
#  ['140693', ' 원작 만화 보신 라면 굳이 영화 보실 필요 없 겁니', '5'],
#  ['140693', ' 꽤 잘만 좀비 영화 생각 듬', '8'],
#  ['140693', ' 비위 약하면 보지 마시 허 접한 티 나면 징 그러 움', '5'],
#  ['140693', ' 진짜 기 괴한 영화', '6'],
#  ['140693', ' 보기 힘들 정도 거북 하다', '3'],
#  ['140693', ' 부산 행 때문 보게 된 영화 여러 에서 부산 행 미치 합', '5'],
#  ['140693', ' 역시 좀비 서양 좀비', '5'],
#  ['140693', ' 좀비 영화 좋아하는 이건 진짜 조잡 하다 평점 처음 남겨 본', '1'],
#  ['140693', ' 원작 만화 그대로 영화 했 더 망했 이 정도 선방 거임', '10'],
#  ['140693', ' 거 보면 웃고 좋아하는 사람 정신 세계 궁금했', '1'],
#  ['140693',
#   ' 왜 굳이 부산 행 비교 할 드는 이해 할 수가 없다 어떻 게 한쪽 아내 리 싶은 건가 진짴 이런 보면 진짜 대한민국 끝없 경쟁 사회 산 아주 뼈 저리 느껴진',
#   '10'],
#  ['140693',
#   ' 솔직히 부산 행 먼저 보고 거 봣을때 둘 재밋 정도 비슷하다 느꼇는데 얼마 전 부산 행 시보 부산 행 너무 재미없 느껴짐 개인 아이엠 어 히어로 부산 행보 재밋엇음',
#   '9'],
#  ['140693', ' 원작 만화 아청 물 진로 변경 개노', '1'],
#  ['140693', ' 특수 효과 재능 낭비 답답하고 꽉 막힌 뚫어 사람 없다', '1'],
#  ['140693', ' 평점 높고 재밌어 보이지 응 재미있어 너무 재밌어 번 봐 지금 또 보러 간다', '1'],
#  ['140693', ' 검색 당신 루저', '1'],
#  ['140693', ' 역시 일본 영화 기적 몇개 빼고', '1'],
#  ['140693',
#   ' 좀비 물의 스토리 거기 거기 더 이상 창조할 신박 스토리 없다 좀비 외형 매우 기괴 보는 사람 불편하며 전개 도중 주인공 빡침 느껴진 반 구울 보이는 척안 로미 무것 하지 않는',
#   '3'],
#  ['140693', ' 기생수 부터 이런 쪽 는 잘 만든', '6'],
#  ['140693',
#   ' 보지 절대 보지 제발 보지 좀비 하드코어 뭐 이 딴 개 소리 듣고 보지 그냥 이건 쓰레기 영화 임 좀비 영화 특유 긴장감 프로도 없고 로코 드라마 영화 장르 불분명 시간 영화 좀비 나오는 분도 안됨',
#   '1'],
#  ['140693', ' 끝 본 내 대견스럽 보고 답답하고 열 받아 평점 남기 첨', '1'],
#  ['140693',
#   ' 평점 낚였 그냥 수많 전형 급 양산 좀비 영화 일 뿐 거기 약간 더 많은 제작비 투자 게 보이는 뿐 별다를 것 없다 이런 유치 쓰레기 같 높게 쳐 사람 애니 오타쿠 거나 쪽문 심취 미취 학 인간 들이 속보',
#   '4'],
#  ['140693', ' 만화 봐 그런 모르 이후 더 재밌 것 같은 느낌', '7'],
#  ['140693',
#   ' 류 영화 괜찮 보았 좀비 흉측 함 신경 쓴 영화 한마디 비위 상하게 만드는 영화 퉤퉷퉷퉷 캬앍 퉷 시간 낭비 했',
#   '1'],
#  ['140693',
#   ' 원작 그렇 이 영화 의문 퍼지 감염 발생했 어째서 사회 조용할 원작 더하던 좀비 사태 발발 일 지났 시민 반응 그닥 걱정 안 심지어 인터넷 좀비 정보 퍼진 주가 넘었 조',
#   '7'],
#  ['140693', ' 초 중반 비해 후반 부가 아쉽 생각 들 충분히 재미있었', '7'],
#  ['140693', ' 어떠한 상황 권력 가지 자는 존재한 노약 관람 피하시', '7'],
#  ['140693', ' 부산 행 노잼 이건 더 재미없 어설픈 겜 흉내 내고 연출 딸리', '1'],
#  ['140693', ' 가수 김연우 좀비 액션 활', '6'],
#  ['140693',
#   ' 솔직히 스케일 스토리 진행 부분 좀 답답하 기도 인물 행동 현실 넘어 이해 안되 기도 했 정도 좀비 영화 본분 다했 중반 부의 도시 탈출 씬 후반 부 대학살씬 매우 훌륭했',
#   '8'],
#  ['140693', ' 원작 만화 때문 재미없 점준 이건 원작 진리 임', '10'],
#  ['140693', ' 주인공 모르모트 피디', '9'],
#  ['140693', ' 일본 진지하게 만든 같은 보는 사람 코미디 보인', '1'],
#  ['140693',
#   ' 평점 너무 낮다 개인 점 영화 평범한 주인공 현실 액션 처음 등장한 주인공 좀비 연기 여고생 외모 별 다섯 개준',
#   '10'],
#  ['140693', ' 부산 행 별로 였 이건 뭐 비교 안되 유치 하네 역시 일본 이런 장르 영화 너무 유치', '1'],
#  ['140693',
#   ' 중간 히토미 주먹질 좀비 때려눕힌건 굉장히 거슬렸 류 영화 류 영화로 내려간 연출 이었 좀비 분장 년대 이후 가장 리얼 했 분장 칭찬해 하다 좀비 물의 정석 따르 일본 분위기 녹아 볼 했',
#   '7'],
#  ['140693', ' 부산 행 현실 스릴 있었 좋 게다가 주인공 버프 너무 심하다 물렸 상황 물려', '6'],
#  ['140693',
#   ' 다리 대준 채 버둥거려 들이 물 않아 주인공 버프 욕 나오는 수준 빼면 영화 자체 상당히 괜찮 오다 츠 구미역 여신 데려 점 너무 예뻐 정신 놓 봄',
#   '10'],
#  ['140693', ' 일본 영화 전대물 스 멜 너무 강해서 몰입 감 떨어진 고어 면 때문 점줌', '5'],
#  ['140693',
#   ' 좀비 영화 가져가야 할 것 중 많 갖춘 편이 전체 완성 도 기대 부산 행 비하면 좀비 물 로서 나쁘 않다 좀비 영화 역시 총',
#   '7'],
#  ['140693',
#   ' 만화 원작 실사 일본 영화 답 고 할 배우 캐릭터 연기 만화 같은 점 아쉬웠 내용 전개 자체 참신 흥미진진 했',
#   '8'],
#  ['140693', ' 나름 졸잼 난 재밌게 봄 부산 행 진짜 애교 수준', '9'],
#  ['140693', ' 주인공 색휘 매번 자 빠져 일어날 모른 장 애 인 이 었 보다 재미 없고 감동 없고 웃음 없다', '1'],
#  ['140693', ' 난 재밌게 봄 평점 낮아 긴장 핬 데', '10'],
#  ['140693', ' 로미 왜 무것 안해 기대했 체 생 좀비 정말 꿈 나올 두렵', '6'],
#  ['140693', ' 캐비넷 계속 나와 물리 장면 진짜 웃겼 징 그러 장면 많아 했 기억 볼 했', '10'],
#  ['140693', ' 솔직히 이영화 재미 없냐 불 끄 누워 봐봐 시간 가는 몰랐', '9'],
#  ['140693', ' 사실 내용 모르 초반 좀 재밌었 영화 정준일 나오길 국가수 일본 영화 찍네 했 일본 배우 좀 닮은', '7'],
#  ['140693',
#   ' 좀비 사투 장면 단연 최고 였 나머지 드라마 전개 과정 일본 영화 특유 정적 의미 없는 대화 많았 원작 작가 아이 엠 레전드 의 영향 받은 아닐',
#   '7'],
#  ['140693', ' 인정하기 싫지 부산 행보 나', '10'],
#  ['140693',
#   ' 최고 영화 중독 개 쩔 가비 위 높은 건지 좀비 별로 안 무서웠 다만 제일 첫 주인공 여친 조금 소름 였 편도 꼭 나와 줬 하는 영화',
#   '10'],
#  ['140693',
#   ' 원작 만화 먼저 봐 런가 내용 똑같 영화 재미 없네 좀 뭐랄 계속 진지하던 갑갑하기 하고 상황 설정 너무 말 안되 부산 행 만들었 싶은 생각 계속 했 좀비 매니아 로써 좀 실망 크',
#   '4'],
#  ['140693', ' 긴장감 없는 피 튀 기기 향연 너무 익숙해져 버린 뛰 죽이는 반복', '4'],
#  ['140693', ' 로미 왜 무것 안 했 머리 화살 맞아 약해진 걸 이해했', '8'],
#  ['140693', ' 원작 보신 절대 보지 마시 설마 봤 일본 원작 말 먹기 게임 계속 됩', '1'],
#  ['140693',
#   ' 고멘나사이 미소녀 양 아치 넣으 안되 세계 사랑한 일본 타령 알 영화 시작 일본만화 최고 타령 질 일본 영화 지친 맨 더 다크 오텁시 오브 제 인도 재밌게 봤 이영화 두 영화 비하면 점',
#   '2'],
#  ['140693', ' 마지막 허무 볼 했', '8'],
#  ['140693', ' 끝 몰입 하면 봤 카스 미 이뻐', '10'],
#  ['140693', ' 아이엠 어 히어로 만화책 봤 영화 참 만들었 리얼 좀비 영화', '10'],
#  ['140693', ' 로미 왜 무것 안 하냐 변하고 나서 처음 냥 펀치 잘 하더 아니 애초 왜 고양이 된 고양이 물렸다', '5'],
#  ['140693', ' 주인공 너무 비루 하게 만들어 스토리 약간 답답한 아쉽', '5'],
#  ['140693', ' 마지막 히로 미가 뭔가 할 줄 알', '8'],
#  ['140693', ' 일본 점수 낮게', '1'],
#  ['140693',
#   ' 일본 영화 사랑하고 좀비 물 좋아하는 팬 좀비 영화 다양하게 제작 되어 나오는 매우 환영할 일이 나다 여기 에서 일본 영화 특유 엔딩 마음 들 않는 그럼 불구하고 괜찮 영화',
#   '6'],
#  ['140693', ' 내용 뭔가 빈약 것 같은 화끈 연출 맘 듦', '6'],
#  ['140693',
#   ' 제 리뷰 쓰는 내용 너무 어처구니 없어 씁 대호 최민식 호랑이 우정 스토리 라면 이 영화 히데 오 만화가 와 로미 여고생 의 우정 스토리 개연 도 없 핵 노잼',
#   '1'],
#  ['140693', ' 는 아니 한 내려와 평점', '2'],
#  ['140693', ' 거 좀비 영화 가요 코미 딕 영화 가요', '5'],
#  ['140693',
#   ' 주인공 가장 현실 좀비 영화 좀비 히어로 물이 판 곳 현실 히어로 물이 탄생했 본 그 캐비넷 나오는 상상하는 씬 너무 인상 깊어',
#   '10'],
#  ['140693', ' 좀 프리미어 떠 봤 좀비 퀄리티 좋 점 중간 지루해서 돌리 기함', '6'],
#  ['140693', ' 본격 암 유발 영화 캐릭터 저능 아들 있', '1'],
#  ['140693', ' 히로 미가 활약 했 정말 재밌었 짐짝 되어서 아쉽 육상 선수 스 셔 무비 버금 가는 연출 참 재밌게 봤', '7'],
#  ['140693', ' 도청 어떻 시간 안 그려 이 미 친 작가', '10'],
#  ['140693', ' 솔직히 부산 행 하다', '5'],
#  ['140693', ' 예고편 끝', '3'],
#  ['140693', ' 예쁜 애 절대 안 물리 물려 좀비 안됨 여자 고딩 애 완전 짐', '2'],
#  ['140693', ' 점도 아깝', '1'],
#  ['140693', ' 과거 머물러 있지 히어로 되', '8'],
#  ['140693', ' 쇠퇴 일본 영화계 현재 대변 한', '1'],
#  ['140693',
#   ' 소재 신선했 지능 좀비 출현 정작 활약 이렇 다할 없다 좀비 리얼 함 좋 그냥 평범한 좀비 영화 남 주인공 갑자기 물약 빨 나 급 세지 어이 없는 전개 어이 없는 전개',
#   '1'],
#  ['140693', ' 좋 이쁜이 둘', '7'],
#  ['140693', ' 역시 일본 영화 시간 버렸', '3'],
#  ['140693', ' 부산 행보 거 보면 노잼 임 주인공 전 답답함', '4'],
#  ['140693', ' 여주 이쁘 재미없', '5'],
#  ['140693',
#   ' 처음 분 가량 완전 최고 였 중간 여고생 좀비 괴상 설정 나오 몰입도 너무 떨어 트림 나머지 부분 분명히 볼 장면 많기 때문 충분히 괜 찬 좀비 물 하드코어 해서 좋',
#   '8'],
#  ['140693', ' 중반 루즈 하게 늘어지 했 좀더 높은 평점 될 있었 조금 아쉬운 전개', '7'],
#  ['140693',
#   ' 도대체 이 겁나 유치 재미없 영화 어떤 놈 부산 행보 수작 거 다운 받아 보 미치는 줄 알 내 돈 시간 돌려',
#   '2'],
#  ['140693', ' 끝 약간 허무 하게 끝나도 최근 나온 좀비 영화 가장 최고', '9'],
#  ['140693',
#   ' 점심 뭐 먹었 물었 이름 상식 입니 하는 영화 대사 캐릭터 설정 모든 억지 스럽 스토리 연출 한 한몫 한 했 더 좋 생각 너무 드는 영화',
#   '5'],
#  ['140693', ' 독특하고 재미있다 좀비 행동 인상', '10'],
#  ['140693',
#   ' 잘 만든 영화 영상 미도 좋 대사도 재미있 너무 뻔하고 예상 가서 그닥 할 정도 아니었 일본 고어 함 역시 굉장히 잘 나타냄',
#   '7'],
#  ['140693',
#   ' 만화 보는 히로 미가 히데 오 왜 반했 이해 갔 영화로 실물 보 이해 간다 순수하고 정의 귀여운 남자 나도 반할 뻔',
#   '9'],
#  ['140693', ' 부산 행 낫다 인정 하면 영 알', '8'],
#  ['140693', ' 초반 볼 했 먼 끝 끌 가질 하네 원작 보진 않아 모르 로미 캐릭 왜 있는 모르', '8'],
#  ['140693', ' 무슨 텟코 성격 파탄 만들어 로미 또 왜 식물인간 만들어 높이뛰기 좀비 원작 다른 이우 좀비 괜찮', '6'],
#  ['140693', ' 아포칼립스 물 굉장히 하드 한편 속한 분장 훌륭하고 도 훌륭해서 돈 쓴 티 난 그것 눈요기 용', '6'],
#  ['140693', ' 봤 나름 재미있네 나름 만들었', '10'],
#  ['140693',
#   ' 놔 씨 머 부산 행보 낫다 거 무조건 잔 하면 좀비 영화 이건 머 원작 만화 보다 못 연출 엉망 다가 역시 일본 배우 특이한 연극 무대 봄직 독백 하는 어색한 연기 굳이 칭찬하자 특수분장 그럴듯하다',
#   '1'],
#  ['140693',
#   ' 스토리 뭐 무것 없고 주인공 너무 답답하다 진심 돈 주고 보기 너무 아까운 영화 여기 평 들보 부산 행 비교하고 부산 행 낫다 이런 영화 비교 불가 입니 좀비 영화 광팬 너무 재미없',
#   '1'],
#  ['140693', ' 데 드라이 징 영화 같다 역시 일본', '6'],
#  ['140693',
#   ' 초반 부 뛰어난 분장 기술 고어 효과 감탄 했 갈수록 영화 무게 감은 후지산 최근 기생수 작품 그 특유 일본 영화 분위기 대한 편견 좀 사라졌 싶었 이 작품 편견 다시 극 달 했',
#   '6'],
#  ['140693', ' 진짜 로미 뭐임 얼굴 알리 나온 임 점 줄 히로 미짱 나서 점줌 다만 영환 재밌', '5'],
#  ['140693',
#   ' 이용철 평 재미없 말 없는 소설 쓰 까고 일본 영화 알바 없다 소린 국내 배급사 돈 벌어 되는 정식 수입 본인 같으 홍보 안',
#   '5'],
#  ['140693', ' 일본 느낌 물씬 묻 나오는 영화 개연 성은 정말 부족하다', '7'],
#  ['140693', ' 좀비 영화 진짜 좋아해서 거의 봤 평점 너무 높다 점 정도 적당한 듯', '1'],
#  ['140693', ' 내 차라리 부산 행 한 번 더 보고 말', '4'],
#  ['140693',
#   ' 일본 좀비 영화 있어 대작 아닌 싶다 사람 사는 듯 배경 좀비 있는 것 긴장감 주었 백화점 씬 인상 깊었 그 일본 여자 이뻤 진짜 이뻤',
#   '9'],
#  ['140693', ' 보는 소름 돋으 재미있었', '9'],
#  ['140693', ' 좀비 물 역시 잔인 해야 돼', '9'],
#  ['140693', ' 너무 기대 했', '6'],
#  ['140693',
#   ' 내 본 좀비 영화 최고 였 부산 행 따위 허 접하고 개연 없는 영화 비교할 없는 철학 담겨 다만 로미 존재 감 아쉽 했',
#   '10'],
#  ['140693', ' 분 보다 끔 봤 봐 암 점임 그냥', '1'],
#  ['140693', ' 머리 터지는 는 탈 아시아 영화 쓰레기 좀비 영화 이 영화 비하면 부산 행 깐느 갈 수준', '5'],
#  ['140693', ' 이 좀비 물 고어 물', '1'],
#  ['140693', ' 소신 껏 준 졸지 않았 것 생각하면 더 줘 졸았 정말 기대 했', '1'],
#  ['140693', ' 좀비 영화 최고다', '10'],
#  ['140693', ' 평점 너무 낮은 재밌는', '10'],
#  ['140693', ' 원작 디테일 버려 버린 중년 알카포네 판타지 마사미 나나 젠 아줌마 된 세월 무상', '6'],
#  ['140693', ' 토 렌트 보길 다행 지루해', '1'],
#  ['140693', ' 진짜 재밌게 봤 덜덜 만화책 더 재밌네', '10'],
#  ['140693',
#   ' 초반 스케일 굉장히 클 알 별거 없었 초 중반 흥미진진 했 중반 이후 캐릭터 이상하고 병맛 같은 설정 연속 로미 만들어 활용 거의 없',
#   '5'],
#  ['140693', ' 재미있더 난 부산 행 더 재미있었', '8'],
#  ['140693', ' 초반 아쉽 후반 좀비 캐릭 좋 주연 연기 좋 액션 볼 만하 탄 기다려', '7'],
#  ['140693', ' 알바 득실 하구', '4'],
#  ['140693', ' 이건 나름 수작 임 편 기대됨', '9'],
#  ['140693', ' 젠장 평점 보고 볼 걸 그랬 평 남기는 아깝 보지 머시', '4'],
#  ['140693', ' 피 범벅 점철 된 평범한 좀비 영화', '6'],
#  ['140693', ' 거 만화 완전 막장 데 좀비 합체함', '5'],
#  ['140693', ' 개꿀잼 높이뛰기 선수 개극혐', '9'],
#  ['140693', ' 내 시간 돌려', '1'],
#  ['140693', ' 내용 미흡 샷건 시원 시원함 점 줄라 다가 점수 낮아 점', '9'],
#  ['140693', ' 후속 편이 나오려', '7'],
#  ['140693', ' 그냥 시간 떼 기용 보세', '5'],
#  ['140693', ' 일본 특 유의 별것 아닌 감동 만들기', '6'],
#  ['140693', ' 잔인함 남고 스토리 감동 남지 않는 일본 답', '4'],
#  ['140693',
#   ' 부산 행 헐리웃 좀비 물 그냥 한글 더빙 보 여준 느낌 아이엠 어 히어로 좀비 소재 완벽하게 일본 재탄생 시킨 느낌 애초 세 좀비 웬말 히로 미가 너무 하는 없고 왜 변종 된 건지 설명 없어 마이너스',
#   '8'],
#  ['140693', ' 니 애니 만들어 영화 진심 아닌 것 같다', '1'],
#  ['140693',
#   ' 만화 원작 훌륭한 실사판 불필요한 부분 과 감히 삭제 뛰어난 연출 배우 연기 덕 잘 만들었 개연 부족한 단점',
#   '8'],
#  ['140693', ' 부산 행보 재밋당', '10'],
#  ['140693', ' 좀비 물이 금 딱지 붙어 하는 좋 예', '10'],
#  ['140693', ' 예고편 개낚임 유치 주인공 진짜 답답하다', '1'],
#  ['140693', ' 결과 없는 변화 용기 대한 메세지 담고', '7'],
#  ['140693', ' 귀염둥이 로미 주인공 좀 도와줬', '7'],
#  ['140693',
#   ' 평론가 평점 믿지 원작 만화 본 사람 라면 충분히 재미있 실 원작 캐릭터 성격 좀 다르 후속작 나올 예정 스토리 이어짐',
#   '10'],
#  ['140693', ' 쓰레기 수준 노잼 지루함 스토리 망작 현실 제로 주인공 답답 로미 무 쓸모', '3'],
#  ['140693', ' 생각 나쁘 않고 일본 코스프레 영화 아니 놀랐 무엇 좀비 표현 헐리웃 비교해도 압', '7'],
#  ['140693', ' 초반 좀 지루하 하이라이트 뒷 부분', '8'],
#  ['140693', ' 참 재미있었', '7'],
#  ['140693', ' 남 발암 일으키는 인물 역시 일본 영화 답 초반 중반 부분 지루하게 시간 끄 후반 부 볼 만하', '5'],
#  ['140693', ' 유치 할 생각 햇 데 생각 재밌게 봤 나가 사와 마사미 로미 굉장히 닮았', '6'],
#  ['140693',
#   ' 거 보고 재미있다 하는 애 진짜 알바 뭐 부산 행 애교 어떤 미친 놈 거 비교하냐 이영화 그냥 쓰레기 진짜 퀄리티 스토리 모든 쓰래 기 보지 그냥',
#   '1'],
#  ['140693',
#   ' 좀비 무섭 혐오 건 당연 부산 행 은 얘 들 너무 역겹 구토 유발할 뻔 세상 뒤집어져 답답한 주인공 연기 최고 주인공 하는 짓 볼때 진 짜 답 답',
#   '4'],
#  ['140693',
#   ' 일본 영화 일본 영화 답지 않아 좋 좀비 영화 잔인 장면 안 나올 수가 있 일본 쓸 데 없는 잔인함 집어 넣는 경향 있는 이 영화 그런 게 없어 좋 남 주인공 연기 담 하게 정말 잘 한 듯 꽤 재밌었',
#   '8'],
#  ['140693',
#   ' 좀비 물이 일본 특유 유치 함 만났 때 초반 좀 재밌으 싶더 여타 좀비 영화 익히 봐온 동선 타며 새 로움 대한 기대 사라진 급작 전개 깊이 없는 캐릭터 뭐 때문 되 묻 기를 수 차례 그냥 그러 따라오 지친',
#   '3'],
#  ['140693', ' 로미 존재 감 부각 시키 그냥 하는 없는 쩌리 였 그냥 시간 남 때 킬링 용 적합한 수준', '6'],
#  ['140693', ' 좀비 물 좋아하는 재미있게 봤', '10'],
#  ['140693',
#   ' 자고로 좀비 영화 금 붙이 래야 됨 잔인 리얼 부산 행 부 애 강조하는 아동 용 좀비 물 현실 퀄리티 높',
#   '9'],
#  ['140693', ' 로미 역할 좀 아쉽 여기 대 반전 있어 마지막 보스 좀비 한국 배우 임 대반 전', '8'],
#  ['140693', ' 히로 미가 뭔가 해줄 아이엠 히어로 제목 좀비 영화 뭐 했 젤 어울리는 제목', '10'],
#  ['140693', ' 주인공 색끼 너무 찐 따라 빡치는 영화', '1'],
#  ['140693', ' 부산 행보 난이 더', '8'],
#  ['140693', ' 좀비 매니아 만족스런 영화', '10'],
#  ['140693', ' 원작 능가 할 순 없다 공백', '7'],
#  ['140693', ' 좀비 컨셉 분장 말 볼게 없다', '1'],
#  ['140693', ' 뭔가 대화 없고 배경음악 만 나오네', '1'],
#  ['140693', ' 우리나라 파주 아울렛 망한 곳 후지 아울렛 무슨', '6'],
#  ['140693',
#   ' 긴 시리즈 나와 좋 같긴 한편 담기 한계 있었 좀비 물 좋아하는 사람 연출 잘하고 지루한 점 없었 생각합',
#   '10'],
#  ['140693',
#   ' 좀비 영화 매니아 재밌었 코믹 부분 좀비랜드 장소 새벽 저주 여자 주인공 초인 힘 웜우드 엔딩 주시 리즈 모티브 것 같네 재밌게 보신 웜우드 추천합 여고생 나중 웜 우드 될 것 같고 시리즈 나올 하네',
#   '7'],
#  ['140693', ' 영화 후지 만들 수 있', '4'],
#  ['140693', ' 아주 그냥 부산 행 살 애기 구만 얼굴 터지 뭐 하는', '1'],
#  ['140693',
#   ' 서양 판 좀비 영화 주연 다양한 무기 일당 무쌍 찍는 재미 있었 이영화 주인공 샷건 플레이 제외하고 일기토 털리 무장 히키코모리 사실 보는 재미 있다',
#   '9'],
#  ['140693', ' 마지막 체 생 좀비 턱 아니냐', '10'],
#  ['140693', ' 이 레알 좀비 재미있게 잘 봤', '10'],
#  ['140693',
#   ' 간만 일본 영화 보고 박진 감 넘쳤 네티즌 평점 낮은 일본 나라 때문 듯 좀비 물 좋아하는 분 들 강추 느릿느릿 일본 영화 상상하고 보시 깜짝 놀랍',
#   '10'],
#  ['140693', ' 일본 애니메이션 좋 영화 아닌 같다', '1'],
#  ['140693',
#   ' 이 정도 좀비 영화 중 수작 물론 원작 개연 시간 안 담기 무리 있었 좀비 영화 예술 바라는 분 로메 감독 꺼 보 좀비 영화 무 생각 보는 게 최고다 많 바라지 마라 부산 행 같은 신파 훨 낫다',
#   '9'],
#  ['140693', ' 금 천만 영화 히데 오강 추', '9'],
#  ['140693', ' 스릴 있고 괜찮 한가지 이상한 무슨 좀비 초인 아니 맨손 사람 머리 깰 그리 로미 여주 왜 넣 암것 안', '6'],
#  ['140693', ' 좀비 물 좋아하는 사람 놓치 아쉬 작품', '10'],
#  ['140693',
#   ' 바이오하자드 실사판 보는 같았 큰 감흥 없으 그냥 시각 부분 때문 볼 했 솔직히 스토리 어린이 용 전대물 같다 해야 할 나',
#   '6'],
#  ['140693', ' 여기 별점 개 이상주 새기는 최소 알바 천국 사기 애', '1'],
#  ['140693', ' 갠 부산 행 이 낫다 다운 받아 볼 킬링 용', '1'],
#  ['140693', ' 연출 볼 했 좋 기술 가지 스토리 개판 왜', '5'],
#  ['140693', ' 김연우 주인공', '5'],
#  ['140693',
#   ' 만화 내용 영화 하면 조금 변형 했 이 무엇 좋 마지막 발의 총격 신 도 좋 중간 길 걷다 마주 하게 되는 택시 타기 전 상황씬 아주 좋',
#   '10'],
#  ['140693', ' 더러운 혐한 물 일본 놈 넷 조센징 죽이는 영화 좋 죽더 혐한 물 한국인 배우 한국 케 만든 최초 사례', '1'],
#  ['140693',
#   ' 모든 좀비 배우 한국인 채운 영화 심지어 로케 한국 거 이영화 한국 찍 이유 뭘 까 참고 대표 한국인 좀비 묘사한 세번 작품 이런 혐한 물 좋 보고 평점 높게 주는 놈 박근혜 똥 불러',
#   '1'],
#  ['140693',
#   ' 히데 오 각성 좀 더 중반 이뤄지 후반 부 강렬한 신 기대했 흡입 약했 다만 만화 실사 하는 일본 영화 산업 이전 배 나아진',
#   '6'],
#  ['140693', ' 초반 개 중간 어떤 놈 비 비탄 총 쏘고 어의 없는 영화 국내 흥행 안된 이유 있 재미 없으', '3'],
#  ['140693', ' 감독 끊임없 연관 없는 내용 향연 할 말 잃었', '1'],
#  ['140693', ' 일본 영화 특유 좀비 물', '8'],
#  ['140693', ' 남 주가 김진표 똑 재밌게 봤', '10'],
#  ['140693', ' 이태 본 일본 영화 제일 재미있게 본 같다', '9'],
#  ['140693', ' 감정 요소 표현 과장 치중 상급 좀비 물 개인 부산 행보 낫다 생각한', '6'],
#  ['140693', ' 윽 김연우 일본 진출한 피 범벅 무비 무셔', '7'],
#  ['140693', ' 내용 중점 뒀 잔인 연출 중점 둬 그런 보는 적응 안되 거북 했 잔인 거 좋아하는 사람 보세', '1'],
#  ['140693', ' 영화 임 거 왜 봤 개 빡치 돈 주고 봤 될 뻔했', '1'],
#  ['140693', ' 단편 생각하고 만들었 그럭저럭 갠찮 수준', '7'],
#  ['140693',
#   ' 지루한 좀비 물 인 스릴 없고 감동 없고 어떻 걸 부산 행보 재미있다 할 수 있는 궁금타 어 내 아까운 시간',
#   '1'],
#  ['140693',
#   ' 도대체 여고생 이쁜 왜 역할 없 처음 쌘 캐릭 나오고 끝 잠 자냐 편집 건 진짜 어이 없는 스토리 전개 봤',
#   '6'],
#  ['140693',
#   ' 재미있게 봤 충실 일본 좀비 영화 주인공 엽총 쏘기 시작하자 저돌 좀비 슬로우 스탭 좀비 매니아 이해하지 할 그냥 일본 좀비 물 여배우 이쁘 그거 된거 말하면 납득 되는 영화',
#   '10'],
#  ['140693',
#   ' 히데 오 명 손바닥 편 암시 하는 난 일본 싫어하지 머 평가 냉정 해야 일본 좀비 울 좀비 낫 체 좀비 닝 마라톤 좀비 수영 좀비 탁구 좀비 축구 좀비 역도 좀비 레슬링 좀비 농구 좀비 스키 좀비 사격 좀비',
#   '8'],
#  ['140693', ' 부산 행 급 다르 역시 일본 좀비 물', '8'],
#  ['140693', ' 야한 장면 없 그냥 고어 물 무섭 않 일본 좀비 분장 잘했', '5'],
#  ['140693',
#   ' 왜 애니 원작 일본 영화 걸 하는 또한 번 확인 시켜 준 영화 좀비 얼굴 티 너무나 전개도 허 접 주인공 개 자체',
#   '3'],
#  ['140693', ' 좀비 영화 가장 중요한 좀비 데스 씬 잔인 스릴 있게 잘 녹아', '9'],
#  ['140693', ' 근래 본 영화 가장 쓰레기', '2'],
#  ['140693', ' 개인 난 부산 행 보다 재미있다 총 다른 무기 제대로 드는 주인공 좀 짜증 나긴 부산 행 보다 낫다', '9'],
#  ['140693', ' 노잼 부산 행 더 재미있', '2'],
#  ['140693', ' 역시 좀비 영화 이래 볼맛 나지', '8'],
#  ['140693', ' 만화책 보고 보니 재미 반감', '6'],
#  ['140693',
#   ' 와 진짜 미국 좀비 보다 일본 정통 좀비 물 보 개 재밌다 와 이런 영화 일본 간만 대작 하나 만들었 진짜 재밌 분장 퀄리티 굿',
#   '10'],
#  ['140693', ' 남 주가 찌 함 극치', '5'],
#  ['140693', ' 만화 원작 진짜 표현함', '10'],
#  ['140693',
#   ' 취향 탈 것 같아 부산 행보 괜찮 해서 나름 기대했 좀 지루했 편이 나온 볼 것 같지 남 보라 추천 안 할 겁니',
#   '6'],
#  ['140693', ' 로미 뭔가 해줄 알 역시 끝 해줄 알 끝났', '6'],
#  ['140693', ' 오 네 가', '9'],
#  ['140693',
#   ' 중반 부가 약간 늘어지 하나 초반 고속도로 씬 후반 쇼핑 은 역대 좀비 물 최고 수준 할 부산 행 건전 영화 였',
#   '8'],
#  ['140693', ' 어설픈 와 분장 이 몰입도 떨어뜨린 시나리오', '1'],
#  ['140693',
#   ' 좀비 물 반 코미디 만드는 일본 영화 엄청난 저력 확인했 사실 개인 워낙 기대 봤 기대 봤 땐 오히려 볼 함 지인 워낙 기대하고 나서 세상 나올 욕 욕 다하더',
#   '6'],
#  ['140693', ' 최고 영화 일본 특유 영화 느낌 즐거웠', '10'],
#  ['140693', ' 잔인 더럽 답답하고 찌 함 쓰레기 영화 누가 재밌다 했', '1'],
#  ['140693', ' 볼 했 총알 탄 많았', '10'],
#  ['140693', ' 주인공 찌 개', '1'],
#  ['140693',
#   ' 주인공 성격 때문 답답해서 미칠 같았 히로 미도 무슨 존재 인지도 밝혀지 않고 좀 재밌었 그 육상 선수 좀비 말 도해 여기 좀비',
#   '1'],
#  ['140693', ' 주인공 너무 멋지 나도 지켜 히데 오쿤', '10'],
#  ['140693',
#   ' 봤 좀비 영화 제일 좋 마지막 정말 쾌감 장난 아니 원작 보고 영화 본 원작 다른 점 조금 아쉽 기도 주인공 이름 걸 맞는 히어로 영화 진정 나왔 개인 좋아하는 아현 함 러브스토리 최고 였 정말',
#   '10'],
#  ['140693', ' 주인공 겁나 찌질 답답해 주인공 쓰레기 임', '2'],
#  ['140693', ' 이쁜 아리 무 병풍 뭐 대사도 없어', '7'],
#  ['140693',
#   ' 재미 없어 시간 아깝 더럽 잔 하고 이상한 쇼핑 센터 좀비 펑펑 쏴 죽 끝남 주인공 하는 짓은 답답하고 여고생 뭔가 있 같다 무것 없',
#   '1'],
#  ['140693',
#   ' 재미 없어 시간 아깝 더럽 잔 하고 이상한 쇼핑 센터 좀비 펑펑 쏴 죽 끝남 주인공 하는 짓은 답답하고 여고생 뭔가 있 같다 무것 없',
#   '1'],
#  ['140693',
#   ' 그래 생각했 평점 네 초반 흥미진진 전개 연출 점 이상 시작해서 갈수록 점수 깎아 먹네 여자 배우 분 진짜 이쁘 남는 늦게 이 두 배우 알',
#   '6'],
#  ['140693', ' 크 정도 좀비 영화계 수작', '10'],
#  ['140693', ' 최근 년 사 이본 좀비 영화 제일 잼 났', '10'],
#  ['140693',
#   ' 좀비 분장 초반 스토리 진짜 좋 이쁜 여고생 도망 다니 매력 감동 느낄 수 있 알 여고생 이제 뭔가 나올 때 됬 다하면 암것 안 끝 소재 좋 스토리 아쉬웠 뿐 여고생 케릭 터 잘 살렸',
#   '3'],
#  ['140693', ' 장르 규칙 충실 하면 서도 참신 하기 쉽 않은 아마 원작 힘 일', '9'],
#  ['140693', ' 왜 로미 완벽하게 감 연안 된 안나 오고 일단 역대 주인공 버프 받으 살 진짜 핷 노잼', '1'],
#  ['140693',
#   ' 이 부산 행보 나은 점 잔인함 개성 있는 좀비 뿐 사실 좀비 매니아 그 두 가지 높게 따지 경향 있기 함',
#   '6'],
#  ['140693', ' 장난 하지 마세 정말 쓰레기 영화 전혀 감동 지도 않고 재미있지 않고 내용 없어', '1'],
#  ['140693', ' 초반 몰입 감 긴장감 최고 다만 중반 부 이후 몰입 요소 방해하는 들이 너무 많다', '6'],
#  ['140693', ' 재미있네 일본 좀비 영화 기대했 진짜 끝 볼 했', '10'],
#  ['140693',
#   ' 진심 이 재밌 독특함 하나 없는 흔해 빠진 좀비 물 좀비 물 태어나서 처음 본 사람 이면 재밌다 이해 가겠 일본 그냥 영화 만들어 스릴러 류 도무지 아닌',
#   '1'],
#  ['140693',
#   ' 주인공 죽었 좋 몇 안되는 영화 하나 중 히데 오가 그린 만화 주인공 그렇 진짜 노 매력 하는 짓 이해도 안되 답답하면 찌질 꼴 보기 싫은 캐릭터 일본 애 확실히 혼 이상해 짜증 나게 잔인함',
#   '4'],
#  ['140693', ' 쪽바리 종특 설명 회 보고 온 기분', '4'],
#  ['140693', ' 여자 주인공 예쁨 일본 왜 여고생 코스 프레임 그냥 있어 이쁜', '8'],
#  ['140693', ' 새로운 장르 출현 좀비 코스프레', '1'],
#  ['140693', ' 꽤 재밌었 몰입 잘된', '10'],
#  ['140693',
#   ' 와 기발 상상력 좀비 영화 라면 정돈 되 야한 봅 새벽 저주 일후 주후 월드 워 나 전설 와 꼭 봐 야할 좀비 영화 생각합 좀비 물 매니아 라면 꼭 보시',
#   '10'],
#  ['140693', ' 좀비 마니아 좋아할 피칠갑 액션 머리 터 트리 기 하드코어', '9'],
#  ['140693', ' 솔직하게 너무 실망했 일본 영화 좋아하지 이건 쫌', '3'],
#  ['140693',
#   ' 이 딴게 왜케 평점 높냐 정말 쓰레기 였 보는 기대했 마지막 부분 그거 하나 볼 완전 슈렉 였 좀 속 시원하고 좀비 학살 하는 전 사용 좀비 물 없냐',
#   '1'],
#  ['140693',
#   ' 일본 영화 왜 안되는 보여 좋 예 구성 연출 영상 음악 전부 공포 질 이었 배우 위 연기 히데 오역 제외하고 너무 어설펐 짜임새 볼 수 없는 그냥 시간 시간 쓰레기통 쳐 박은 느낌',
#   '3'],
#  ['140693',
#   ' 초반 이삼십 분 볼 만 그 이후 론 오락실 원 넣고 좀비 총질 하는 나 일반인 개취 기자 평론가 평점 요즘 수준 떨어졌 간혹 거리 장면 땜 후 하게 점 줌',
#   '3'],
#  ['140693', ' 좀비 물 좋아하신 볼 합', '7'],
#  ['140693', ' 잘 만들었 엔딩 나오는 음악 죽이 기대 않 보셔 재미있게 보실 있', '9'],
#  ['140693', ' 일본 좀비 전혀 기대 햇 데 웃기 잔인 하드코어 뭘 바라는 워킹데드 바라고 봄', '10'],
#  ['140693', ' 너무 재밌게 봤 마지막 진짜 잊 없다', '10'],
#  ['140693', ' 주인공 개 발암 짜증 남 후반 무것 못 버', '6'],
#  ['140693', ' 마블 영화 이영화 원작 별개 보는 눈 가집', '7'],
#  ['140693', ' 찐 따 영화 보는 내내 불편하네', '1'],
#  ['140693',
#   ' 기대는 그냥 평범한 머 저리 밀 덕질 한 보관해 둔 총기 발 정도 탄약 가지 댕기 다니 처음 좀비 나온 말하는 영화 같 결말 비비 탄 총 좀비 쏘다 마지막 그냥 엽총 갈기 끝임 한마디 피바다 끝남',
#   '1'],
#  ['140693', ' 히로 미짱 고양이 사료 먹고 자세 생긴 것 고양이', '10'],
#  ['140693', ' 이 영화 보고 부산 행 진짜 잘 만들었 생각했 우리나라 연기 더 잘한', '4'],
#  ['140693', ' 편 편 나온 전제 점 비슷한 러닝 타임 결말 만들어 낸 부산 행 대단한', '7'],
#  ['140693', ' 유혈 낭자 좀비 사냥 영화 걷기 하던 좀비 뛰 이제 말 하네 중반 부분 지루한 것 빼고 볼', '6'],
#  ['140693',
#   ' 엉망 진창 진짜 초반 부는 스릴 감 느껴지 뒤 갈수록 내용 그닥 점점 고 진행 잔인 씬 원작 정도 읽었 좀더 이해 될런 모르 클레 총 위력 그렇 센',
#   '3'],
#  ['140693',
#   ' 솔직 후기 만화 봐 잘 모르 영화 봄 일단 스토리 그다지 있는 같진 않 좀비 좀 일반 좀비 특이하고 무었 특수 효과 오지 좋 스트레스 풀기 짱임',
#   '6'],
#  ['140693', ' 내용 만화 피 흘리 폭력 영화 기자 뭘 보고 평점 한 걸 의문 든', '1'],
#  ['140693',
#   ' 지금 봤 좀비 영화 제일 쓰레기 좀비 왜 코믹 죽기 기억 남아 체조 하지 않 쇼핑 하지 않 운동선수 출신 좀비 음악 틀어주니 층 층 옥상 점프 하네',
#   '1'],
#  ['140693', ' 부산 행 좀 거 시기 했 그거 더 거 시기 영화', '6'],
#  ['140693', ' 재미 지다 일본 영화 독창 무언가 있다', '10'],
#  ['140693', ' 예고편 보고 재밌 알 배신 기분 좀비 분장 빼고 연기력 연출 너무 떨어진', '4'],
#  ['140693',
#   ' 정말 좋아하는 원작 이었 나름 기존 만화 원작 영화 연기자 수준 높다 건 위안 문제 각본 용구성 다음 엑스트라 촬영 한국 하지 그냥 감독 한국 사람 써',
#   '4'],
#  ['140693',
#   ' 도시 전체 패닉 휩싸 잘 표현한 같 나름 긴장감 있고 아쉬운 점 원작 스토리 너무 길기 때문 삭제 된 부분 너무 많 때문 결말 애매 하게 끝낼 수 없었 같네 전체 스토리 구체 아실 원작 보세',
#   '6'],
#  ['140693', ' 부산 행 얼마나 쓰레기 영화 알 됨', '10'],
#  ['140693',
#   ' 히로 미가 이뻐 점준 점 적당한 영화 같 긴장감 있는 장면 우라가 총 내놓 장면 뿐 운동선수 바이오하자드 시몬 스 연상 시킴 오히려 주인공 찌질 살아남 영화 같네 히로 미가 짱 이뻣음',
#   '8'],
#  ['140693', ' 부산 행 보다 훨 재미 짐 히로 미짱 무슨 역', '8'],
#  ['140693', ' 최근 일본 영화 중 괜찮 편 주인공 싱크로 율', '8'],
#  ['140693',
#   ' 주인공 로미 둘 너무 답답하다 영화 보는 속 터져 뻔했 액션 신경 쓴 같다 이 영화 무엇 의미하는 모르 부산 행 액션 인간 이기심 중점 다룬 영화 였 이건 액션 초점 맞춘 하다',
#   '3'],
#  ['140693', ' 류 쓰레기 영화 지금 본 좀비 물 최악', '1'],
#  ['140693', ' 내 가본 좀비 영화 최악 주인공 답답해서 보다 끄', '1'],
#  ['140693',
#   ' 주인공 캐스팅 무슨 만화 끄 집어 냈 완전 똑같 깜놀 했 기생수 등등 만화 원작 일본 영화 여러 번 실망해서 별 기대는 안 했 나쁘 않았',
#   '9'],
#  ['140693', ' 재밌긴 주인공 암 덩어리', '7'],
#  ['140693',
#   ' 정도 선방 원작 미치 좀비 영화 론 괜찮 처음 쇼핑몰 내용 너무 압축 시켜 좀 혼란 스럽 와중 부역 배우 걸 크러쉬 내 스타일',
#   '7'],
#  ['140693', ' 일본 판 새벽 저주 본 기분 확실히 부산 행 재밌었', '8'],
#  ['140693',
#   ' 의 전개 짜증 난 히데 오가 나약 함 이겨 과정 너무 미련 하게 억지 스럽 로미 존재 이유 가치 뭔 모르 개연 없다 할 연출 너무 아쉬운 영화 좀비 구상 단연 최고 였',
#   '7'],
#  ['140693', ' 부산 행 왜 평점 높은 이유 좀', '10'],
#  ['140693', ' 장난 하나 알바생 겁나 많구 부산 행 귀여워 시간 아깝 댄 장', '1'],
#  ['140693',
#   ' 진짜 재밌게 봤 지루할 틈 없 정도 흥미진진 주인공 찌 착한 남성 모습 더욱 공감 하며 빠져 들 수 있었 같 단순히 잔 영화 아니 용기 가지 찌 이도 영웅 될 수 있다 교훈 있는 영화 였 강추함',
#   '10'],
#  ['140693', ' 볼 만 긴장감 없다', '7'],
#  ['140693',
#   ' 비 비탄 총 현실 뿜었다 점준 비 비탄 그거 맞고 좀비 나 비 비탄 총 소품 쓴 감독 갑자기 여고생 강간 할 하질 진짜 고양이 사기 캐 만들어 무것 안해',
#   '5'],
#  ['140693', ' 액션 잔인 하게 감성 따뜻하게', '9'],
#  ['140693',
#   ' 원작 살렸 원작 뒤 더 내용 있지 스토리 자르는 부분 적당하게 잘 자른 같고 일본 원작 영화 하면 죽쑤는 종특 이건 선방 했',
#   '8'],
#  ['140693', ' 진짜 허졉 류 쓰 렉 영화 평점 남길 로그 인했', '1'],
#  ['140693', ' 보는 히로 미가 어떤 힘 보여 기대하면 봤 마지막 끝', '10'],
#  ['140693', ' 쪽 빠리 영화 정말 재미 없고 최악', '1'],
#  ['140693', ' 부산 행 잼 운동선수 좀비 졸 무서움', '8'],
#  ['140693', ' 오오 이즈미 요 좋아해서 봤 역시 실망 시키 않네 재미있게 봤', '10'],
#  ['140693', ' 장기 자랑 나발 이런 게 좀비 물이 막판 높이뛰기 좀비 결투 긴장 놓치 않게 한', '10'],
#  ['140693', ' 재미있게 봤 두 여배우 너무 이쁘 영화 빠져 들 하네', '10'],
#  ['140693',
#   ' 이 리얼 하게 표현한 좀비 영화 정말 오랜만 봤 주인공 감정 잘 와 닿았 여러 모로 즐겁 봤 개연 조금 아쉬워',
#   '9'],
#  ['140693', ' 아이엠 어 히어로 너무 재밌게 봤 편도 보고', '9'],
#  ['140693', ' 끝 너무 허무 함 어이 없', '6'],
#  ['140693', ' 재미없 분장 좋 았음', '4'],
#  ['140693', ' 무슨 말 더 필요한 나가 사와 마사미 그녀 하나 충분하지 않은', '10'],
#  ['140693', ' 몇몇 장르 신선함 매력 승화 되 하는', '5'],
#  ['140693',
#   ' 후지산 자마자 개 노잼 여고생 대본 외우기 편햇겟음 중반 대사 무것 없네 왜 등장 햇 잔인 거만 재밌네 택시 사고 주인공 살아남 함',
#   '5'],
#  ['140693',
#   ' 꽤 몰입도 있다 일본 특유 오바 연기 좀비 만났 때 각기 좀비 탄생한 분장 진짜 대단하고 샷건 주는 통쾌 함 좋 뭐 스토리 개연 성은 포기하고 보면 눈 즐거움',
#   '8'],
#  ['140693', ' 남 더럽 찌 하네 답답 평점 너무 높은 점 대가 적당함', '1'],
#  ['140693',
#   ' 영화 봤 결말 기 같네 그냥 무것 보여 없어 제목 추천 하나 해드리 제목 파주 아울렛 탈출기 하면 좋 같',
#   '1'],
#  ['140693', ' 예고편 전부 영화', '1'],
#  ['140693', ' 부산 행 저리 라임 이 영화 재밌네', '9'],
#  ['140693', ' 히데 오가 같아 점 준 사내 새끼 개 찐 따', '1'],
#  ['140693', ' 밤 혼자 보는 무서웠 자 부산 행 애교 마사미 나와 점준', '8'],
#  ['140693',
#   ' 개인 부산 행보 노잼 이었 개그 코드 맞고 좀비 느려 답답했 무엇 로미 발암 남 주도 별로 재미 첫 등장한 여자친구 변했 때 느낌',
#   '6'],
#  ['140693', ' 아주 솔직하게 예상 상회 했', '5'],
#  ['140693', ' 부산 행 얼마나 재밌는 알 알반 일뽕 왤케 평점 높아', '1'],
#  ['140693', ' 워킹데드 다져 런가 나 별로 안잔 인했 로미 뭐 하는 애임 왜 암것 안함', '7'],
#  ['140693', ' 여고생 이뻐 점준', '9'],
#  ['140693',
#   ' 긴박 감 잔인함 치중 좀비 물 부산 행 좀 더 영화 같은 느낌 긴장감 부산 행 수위 좀비 묘사 이엠 히어로 수위 잔인 거 싫어하는 분 아이엠 히어로 피하시',
#   '8'],
#  ['140693', ' 처음 참신 줄 알 이건 아니', '6'],
#  ['140693', ' 역시 일본 좀비 물 보는 아니었 일본 애니 봐 야한', '1'],
#  ['140693', ' 부산 행보 약 배 재미있', '10'],
#  ['140693', ' 만화 코스프레 아닌 제대로 된 하나 영화 약간 과 하드 고어 장면 때문 모두 소화하기 어렵', '6'],
#  ['140693', ' 억지 감동 부산 행보 낫', '7'],
#  ['140693',
#   ' 역시 원작 완결 되 않은 작품 실사 하려 결말 없다 그냥 좀비 죽이 끝남 로미 왜 저런 상태 떡밥 회수 못',
#   '1'],
#  ['140693', ' 납득 닮았 조정석 출연한', '1'],
#  ['140693',
#   ' 놔 부산 행 시간 가는 모르 봤 이건 좀더 보면 재밌겠 하고 끝 졸면 봤 잔인 거 빼면 무것 없는 좀비 영화 긴장감 없고 감동 없고 끝 허무 그냥 무 생각 눈 보실 분강추',
#   '4'],
#  ['140693',
#   ' 좀 보다 말 보면 백프로 만화 원작 일 생각했 역시 분장 정말 좋 스토리 조금 더 진중 하게 각색 했 만화가 원작 더 한계 영화 봅 누적 관객 만 이면 망한',
#   '5'],
#  ['140693',
#   ' 스토리 연출 스케일 연기 부산 행보 좋 평점 부산 행보 별로 대단한 애국심 나셨 그냥 인정할 건 인정해 조선 놈',
#   '8'],
#  ['140693', ' 좀비 물 너무 재밌다 로미 너무 이쁘', '9'],
#  ['140693',
#   ' 웬 만화 분위기 나면 코믹 요소 좋 무엇 흔한 좀비 물이 아니 볼 했 영웅 잘생기 돈 많은 근육 질의 미남 있는 아니 평범한 모습 우리 주위 쉽 찾 있었',
#   '8'],
#  ['140693', ' 만화책 재미있게 봤 만들었', '10'],
#  ['140693', ' 징 그럽 산만 하다 로미 뭔가 있 알', '7'],
#  ['140693',
#   ' 부산 행 아동 용이 라면 히어로 성인 용 하드코어 영화 자체 강렬함 남은 총알 발 피바다 킬링타임 용 영화 수준 넘었',
#   '10'],
#  ['140693', ' 난 일본 영화 김연우 주연 등장한 줄', '9'],
#  ['140693',
#   ' 지금껏 본 일본 영화 가장 재미있는 하네 일본 특 유의 유머 액션 잘 어 울어 짐 단 묘사 잔인 심 약한 분 보는 좋',
#   '9'],
#  ['140693', ' 어떤 부산 행보 좋 것 같고 어떤 부분 유치 이상한 괜찮 보기', '9'],
#  ['140693', ' 분장 하나 최고 였', '7'],
#  ['140693', ' 좀비 영화 매니아 환호 부산 행 월드 워 극찬 불호', '7'],
#  ['140693', ' 분장 특수 효과 빼면 부산 행 배 재미있다 역시 니뽕 영화', '4'],
#  ['140693', ' 가장 좀비 영화 다운 좀비 영화', '10'],
#  ['140693', ' 그냥 말 안되 같고 짜증 남 시간 많은 분 보셔 됨', '4'],
#  ['140693',
#   ' 스토리 개판 솔직히 진짜 재미없 전개 방식 그렇 좀비 모습 그렇 너무 코믹 스럽 갠 일본 영화 좋아하지 이 영화 진짜 별로 였 시간 아까웠',
#   '1'],
#  ['140693', ' 마사미 년 지났 여전히 눈부시', '8'],
#  ['140693',
#   ' 일본 영화 특유 어리 버리 큰소리 치기 우리 정서 확실히 맞네 역시 원작 하네 아시아 좀비 영화 가장 수작 요 한국 영화 만드는 좀비 호러 아주 물이 스토리 좋 표현',
#   '8'],
#  ['140693',
#   ' 열린 결말 아쉽 영웅 이름 가진 자의 이름 값 하게 되는 계기 되는 이야기 사람 혼자 힘들 죠큔 능력 치가 제대로 발휘 되 못 영화',
#   '7'],
#  ['140693', ' 볼 함 여배우 이뻐 눈 즐거운 있', '8'],
#  ['140693', ' 별 개도 아까운 영화 잔잔 함 속 잔인함 가득함 내용 없고 감동 없', '1'],
#  ['140693', ' 마지막 아수라 느낌 나고 그냥 잔인 게 계속 나오다 보니 머리 터져 별 느낌 안 오드 고요', '5'],
#  ['140693',
#   ' 내용 산 갈수 없는 이유 만화 원작 내용 저 짧은 시간 안 소화해 하기 때문 과정 중간 중간 빠질 없다 감독 나타내고 하는 좀비 죽이는 저런 평범한 오히려 사회 인정받 못 자도 히어로 될 있다 그거 하나 일 같다',
#   '8'],
#  ['140693',
#   ' 원작 안보 고도 재밌게 본 영화 중간 좀 루즈 초반 아울렛 일 다함 로미 물었 애기 고양이 인 좀비 라면 정도 되 될 같',
#   '10'],
#  ['140693', ' 원작 팬 좀 기대했 그냥 그렇 딱히 추천하고 싶은 영화 아니', '6'],
#  ['140693', ' 간만 보는 심장 쫄깃쫄깃 좀비 물', '9'],
#  ['140693', ' 글자 요약한 용두사미', '1'],
#  ['140693', ' 솔직히 이 좀비 물 같은 좀비 물이 말 안되는 좀비 물려 좀비 됬 사람 공격 안해 뭐 하프 좀비', '1'],
#  ['140693', ' 바람 검심 달라졌 와중 우뢰매 생각나는 진격의거인 로미 무것 할 왜 집어 넣은 원작 저럼', '8'],
#  ['140693', ' 꽤 훌륭한 스타트 점점 산 산', '6'],
#  ['140693',
#   ' 초반 좀 지루함 일반인 그 많은 좀비 사냥 용 총 자루 제압 다는 말 안되는 설정 이긴 킬링타임 용 볼 만하',
#   '5'],
#  ['140693', ' 나 재미있더 원작 잘 살린 일본 영화 오랜만 입니', '9'],
#  ['140693',
#   ' 진행 던지 좀비 룰 그대로 따라가고 있지 타 좀비 영화 틀리 조금 특이한 맛 있었 남자 주인공 물려 변하지 않았 이유 반전 라면 반전 잘 만든 좀비 영화 같다',
#   '10'],
#  ['140693', ' 막판 좀 잔인함 난 인상 그뚱보 좀비 기억 남고 뭐 개인 부산 행 괜 찬', '2'],
#  ['140693',
#   ' 원작 거의 벗어 않고 충실 하게 캐릭 표현 살린 같 그냥 감독 머리 굴 리지 원작 그대로 가라 처음 봤 왜 히어로 이해될 같다 원작 본 사람 부작 올 예상 해볼 로미 넘 이쁘',
#   '10'],
#  ['140693',
#   ' 화끈 잼 영화 전개 아울렛 상황 다소 아쉬운 점 있긴 하나 전반 아주 잘만 좀비 영화 생각 됌 편 나오겠 기대 해본',
#   '9'],
#  ['140693',
#   ' 원작 최대한 비슷하게 노력 보였 긴 용의 원작 스토리 줄 빼다 보니 허 점 보인 좀비 내 여지 껏 본 어떤 좀비 물 가장 퀄리티 있고 징그러웠 좀비 분장 연기 순위 꼽 도 될 정도',
#   '9'],
#  ['140693', ' 만화 보자 원작 반도 따라감', '4'],
#  ['140693', ' 재밌지 않은 그냥 재밌', '8'],
#  ['140693',
#   ' 고딩 때 조아할 자극 잔인성 끝 스토리 개연 성은 버리 잔인함 취한 영화 무 생각 피난 무 즐기 싶다 추천',
#   '3'],
#  ['140693', ' 나름 킬링타임 용 좋 높이뛰기 좀비 한국인 였 거 충격', '9'],
#  ['140693',
#   ' 너무 잔인함 왠만하면 진짜 가리 보는 분 은 좀 가리 봄 와 리얼 징 그러 좀비 진짜 처음 역시 일본 분장 잘하는 싶었 히토미 지능 낮아져 버려 그렇 지 가까이 온 좀비 그냥 작살 낼',
#   '6'],
#  ['140693', ' 잔득 기대했 원작 재미 찾 수 없었 차라리 애니 하는 좋 선택 이었', '4'],
#  ['140693', ' 부산 행하고 비교 될 아님', '4'],
#  ['140693', ' 상당히 잼 봄 부산 행 비교하신 분 많은 부산 행 갇 치우세', '9'],
#  ['140693', ' 부산 행보 잼 속편 기대된', '10'],
#  ['140693',
#   ' 특수 효과 설정 액션 볼 했 일본 특 유의 망 적 내러티브 노답 였 일본 영화 기술 있지 흥행 돼는 이유 여감 보여 생각한',
#   '6'],
#  ['140693', ' 또 예고편 낚였', '2'],
#  ['140693', ' 겁나 지루하다 진심', '1'],
#  ['140693',
#   ' 단순한 가족 애로 떡 칠한 감정 과잉 아빠 아빠 부산 행보 나 특수 효과 캐릭터 영상 배우 모두 합격 점 만능 무기 총 대한 집착 여성 보호 포지션 자리 매김 부분 거슬렸 다음 편 부와 로미 활약 기대한',
#   '8'],
#  ['140693',
#   ' 거 꽤 재밌는 로미 대한 기대 버리 나가 사와 마사미 팬 라면 충분히 개 영화 임 난 갠 구성 부산 행보 훨 나',
#   '10'],
#  ['140693', ' 초반 텟코 좀비 봐 충분히 점 이상 로미 이분 영화 왜 집어넣 거 캐릭터 자체 맥거핀', '8'],
#  ['140693',
#   ' 아리 무 가스 미 출연 이름 스즈키 히데 오 한자 영웅 불러 토코 니 메이 션 나오는 걸 보니 아직 심각한 상황 아니 긴급 뉴스 속보 시작',
#   '6'],
#  ['140693', ' 주인공 겁나 답답하고 일본 특 유의 질질 끄는 전개 더럽 재미없 부산 행 최고', '5'],
#  ['140693', ' 난 나름 잼 있게 봄 기존 좀비 차별 된 뭔가 기 괴한 맛 있고 소심 주인공 캐릭 꽤 잘 그려 냄', '6'],
#  ['140693', ' 일본 영화 서사 약해서 재미 없다', '6'],
#  ['140693', ' 내 걸 왜 본 건지 할 없는 스트레스 쌓인 분만 보세', '3'],
#  ['140693', ' 로미 비중 없어 다소 실망 중반 부 히데 오 한번 구해준 그닥 의미 없어져 버리는 인물', '7'],
#  ['140693', ' 원작 보고 보면 재미없', '5'],
#  ['140693', ' 쓸데없 잔인함 가득 개연 제로 스토리', '1'],
#  ['140693', ' 기억 속 사는 좀비 신선했', '10'],
#  ['140693', ' 부산 행 천만 이 영화 진짜 좀비 영화 유치 부산 행 갖다 버려', '9'],
#  ['140693', ' 미안하지 부산 행보 낫', '10'],
#  ['140693', ' 역시 일본 영화 잔인 게 최고 그냥 그런 좀비 영화 물', '5'],
#  ['140693', ' 진짜 좀비 매니아 좋아하는 영화 입니 단순히 감동 받으 보려 하지 마세', '10'],
#  ['140693', ' 개 노잼 진심 재미없 점 이하 적당', '1'],
#  ['140693',
#   ' 일단 보 느낀 국뽕 빼도 역시 일본 영화 질 한국영 비해 한참 떨어졌 좀비 류 빠돌이 본 편의 좀비 영화 월드 워 위 부산 행 위 거 위정 될 재미 요소 롤렉스 팔 찬 진종오 뺨 치는 원샷 킬 샷건 실력 이었',
#   '6'],
#  ['140693', ' 나름 좀비 퀄리티 좋 엔딩 참 마무리 로미 히어로 되 않는 의미 부여 잼 하는 없고', '6'],
#  ['140693', ' 재밌고 좀 잔인 장면 난 좀 무서웠 높이뛰기 선수 좀비 부산 행보 볼 함', '9'],
#  ['140693',
#   ' 비위 약한 분 보시 것 갠 중반 인간 밑바닥 잘 드러나는 가장 맘 들었 로미 활약 너무 없었 점 좀 아쉽',
#   '8'],
#  ['140693',
#   ' 크게 감탄 건 초반 아비규환 된 도시 좀비 쫒길 때 앵글 시점 마치 영화 속 인물 된 것 처럼 빠져 들 만들어 놀랐 무엇 좀비 매니아 로서 기존 좀비 영화 다르 주인공 찌 하게 설정 것 좀비 과거 산다 설정 참신 했',
#   '8'],
#  ['140693', ' 흠 기존 좀비 물 딱히 다른 없다 내용 자체 지루함', '5'],
#  ['140693', ' 좀비 영화 가뭄 상황 생각 했 일본 좀비 대박 터뜨리 재밌게 잘 봤 후속작 나왔 좋', '8'],
#  ['140693', ' 일본 만화 그대로 놔두는 나 좋 원작 일본 영화로 만들 왜 부자유 지 연기 한국 안 맞', '6'],
#  ['140693', ' 역시 일본 영화 그지같 좀비 생김새 완전 징 그럽 무섭 함 역시 일본 너무 구림', '4'],
#  ['140693',
#   ' 잘만 뛰 핀치 상황 걷는 좀비 만화 영화 하면 일부 인용 일부 변형 하니 개연 문제 생김 마지막 좀비 추측 되는 인간 대량학살 하는 것 마무리 원작 만화 발톱 찌꺼기 못 영화',
#   '1'],
#  ['140693', ' 초반 택시 타기 신선하고 충격 이었 뒤 엔딩 시간 넘게 답답하고 지루함 끝 달림', '5'],
#  ['140693',
#   ' 점 기본 점수 점 좀비 물 점 금 점 스릴러 점 열린 결말 점 로미 점 소재 점 답답한 설정 점 로미 부재 점 내용 부실',
#   '7'],
#  ['140693', ' 평점 알바 풀었', '3'],
#  ['140693', ' 편이 있는 건가 원래 끝나', '5'],
#  ['140693', ' 만화책 원작 한편 담으 해서 떡밥 회수 잘 안된 아쉬웠', '8'],
#  ['140693',
#   ' 좀비 특징 있고 좀비 물 잔인 좋 했 내용 그냥 아울렛 탈출하고 끝임 주인공 갑자기 사기 캐 되는 그렇 여고생 그냥 토템 쳐 앉아 주인공 동기부여 해주는 끝',
#   '1'],
#  ['140693', ' 처음 분 대작 느낌 이 갈수록 일본 영화 되 아쉬웠', '6'],
#  ['140693', ' 솔직히 그닥 일본 부산 행 이영화 비교하면 까 대 봤 기 찬 좀비 물이 고어 물이', '3'],
#  ['140693',
#   ' 재미없 건 아닌 총질 끝내는 영화 기승 전결 부족하다 부산 행 기승 전결 없어 좀더 스토리 좀 짜 약하다 잔인 해',
#   '5'],
#  ['140693', ' 로미 너무 매력', '8'],
#  ['140693', ' 알바 속 봤 정말 질 급 영화 진수 그냥 고어 물 영화 재미 감동 스토리', '1'],
#  ['140693', ' 나 재미없 건가 결말 없고 진짜 예고편 끝', '1'],
#  ['140693', ' 좀비 물 좋아하는 분 괜찮 볼 수 있 듯 결말 부분 좀 허 전하다', '7'],
#  ['140693', ' 오히려 잔인 하다 이런 좀비 개성 너무 뚜렷 웃겼', '5'],
#  ['140693',
#   ' 좀비 매니아 정도 지금 온 모든 명작 류 하류 모든 좀비 영화 를 봣 데 진짜재밋긴재밋 좀비 퀄리티 괞찮 구 중간 중간 웃긴 잇구 다만 히로 미가 뭐좀 할 알구 잇다 끝난 마지막 결말 나 전설 보는 같 짱잼',
#   '10'],
#  ['140693', ' 나가 사와 마사미 바닷 마을 다이어리 인상 깊게', '10'],
#  ['140693', ' 스토리 내용 암것 없고 총질 하다 끝나던 이 잼 유치 뽕짝 개 지루함 극치 번 졸다 봤', '2'],
#  ['140693', ' 구닥 다리 연출 스타일 특수 효과 는 발전하는 왜 일본 영화 연출 스타일 발전 없는 거', '5'],
#  ['140693',
#   ' 원작 각색 했 좀 재밌게 하던 원작 그대로 따라서 시리즈 만드느 훨 나 캐릭터 성격 원작 따라갑 어중간 비슷하게 하지',
#   '5'],
#  ['140693',
#   ' 분장 너무 성하 내용 유치 주인공 연기 좋 긴장감 제로 임 내 우리나라 영화 별로 칭찬 않는 부산 행 더 나',
#   '5'],
#  ['140693', ' 스토리 같은 없고 그냥 주인공 혼자 쌩쑈 총 쏘다 끝 이 영화 게임 이지', '4'],
#  ['140693', ' 일본 좀비 영화 수준', '2'],
#  ['140693', ' 킬링 타임 용 괜찮 완전 일본 영화 일본 망한 이유 있네', '2'],
#  ['140693', ' 부산 행보 잔인 하다 마지막 로미 활약 기대되 실망 시키', '9'],
#  ['140693', ' 예고편 전부 영화 허무 결말', '5'],
#  ['140693',
#   ' 새벽 저주 이후 간만 재 된 좀비 물 일본 기 괴한 상상력 맛있는 작품 찍어 냈 새벽 저주 기생수 첨가 그런 영화',
#   '10'],
#  ['140693', ' 좀비 물 중 역대 최고다 좀비 움직임 잔인함 쩐다 쩔어', '10'],
#  ['140693',
#   ' 이 재밌 쓴 사람 진짜 양심 있는 사람 들이냐 일부러 본 사람 당해 보라 쓴 글임 무슨 영화 잔인 시각 연출 있고 내용 유치 산만 일본 실사영화 왜 망하는 알 됨',
#   '1'],
#  ['140693', ' 좀비 역시 산탄', '10'],
#  ['140693', ' 개 재밌다 거 보고 부산 행 시시 애 장난 일본 영화 이제 무시 하겠', '10'],
#  ['140693', ' 높이뛰기 배우 한국 사람 임', '6'],
#  ['140693', ' 유치 영화 생각하고 봤 진짜 잘 만들었 애니원 작', '10'],
#  ['140693', ' 고어 그 이외 무것 없다 일본 영화 그 자체 형편 없는 영화 임', '1'],
#  ['140693', ' 좀비 움직임 표현 훌륭했 도입 부의 긴장감 끝 유지 시키 한', '7'],
#  ['140693',
#   ' 좀비 영화 대한 개연 부족했 초반 부분 아수라 되는 시내 알 수 없는 공포 대한 묘사 좋 후반 부 들어선 말 안되는 주인공 히데 오 활약 현실 망쳐 버려 재미 반감 그로테스크 장면 좀비 영화 특성 살림 점',
#   '6'],
#  ['140693', ' 이 재밌다 점도 아깝 영화 보는 답답함 떡밥 만들 하는 보이는 편 만들 라그', '1'],
#  ['140693', ' 부산 행보 배는 재미있네 일본 영화 발전했 진짜 재밌게 봤', '8'],
#  ['140693', ' 분볼 만하 시간 분동 안 영화 후지산 간다', '1'],
#  ['140693', ' 많은 내용 담기 영화 한편 부족했 충분히 즐길 했 만화 캐릭터 기형 좀비 나와 더 재미있었', '8'],
#  ['140693', ' 원작 조금 더 살렸 좋 같다 아쉬운 연출 이야기', '6'],
#  ['140693', ' 막장 이야기 재미 입혔', '7'],
#  ['140693', ' 일본 풍만 아니 조금 더 좋 듯', '6'],
#  ['140693', ' 남 주인공 답답함 찌 함 치가 떨린 치가', '5'],
#  ['140693', ' 고어 물 봐 만하 새로운 좀비 묘사 말하는 정확하겠 일본 특유 찌 스토리 봐', '1'],
#  ['140693', ' 메세지 담으 했 연출 후진 영화 안타깝', '3'],
#  ['140693', ' 후속 계속 나옸으 좋', '10'],
#  ['140693',
#   ' 그냥 저그 닥 이임 일본 영화 특징 비현실적 제스처 이영화 맞지 않고 어색하게 갑자기 잡혀 먹히 잔 하고 결말 없고',
#   '5'],
#  ['140693',
#   ' 부산 행 먼저 봐 다행 임 먼저 보고 부산 행 봤 그 돈 아까웠 실감 나서 좋 잔인함 부산 행 좀비 살짝 물 놔 이 영화 좀비 찢고 패 터뜨리 난리 남 그런 난리 통 한 소녀 지키 위한 약한 남자 이야기 듯',
#   '9'],
#  ['140693',
#   ' 역시 좀비 죽여 제맛 좀비 영화 재미 죽는 좀비 수 비례 다는 진리 히로 미가 막 초능력 무쌍 할 알 무것 안 도대체 무슨 역할 도무지 알 없다',
#   '10'],
#  ['140693', ' 만화 원작 있기 때문 이 영화 욕 먹는 것', '3'],
#  ['140693', ' 고어 좋 긴 좀비 자체 묘 하게 별로 임', '8'],
#  ['140693', ' 역시 일본 영화', '5'],
#  ['140693', ' 원작 비교하자 정말 정말 아쉬운 영화', '5'],
#  ['140693', ' 일본 똥 열광 하는 미치광이 바친 쓰레기', '1'],
#  ['140693', ' 좀비 퀄리티 오지 듯', '8'],
#  ['140693',
#   ' 영화 비해 평점 너무 낮네 부산 행보 진짜 재밌다 부산 행 나 영화관 보면 진짜 마동석 아니 환불 하고 정도 망작',
#   '10'],
#  ['140693', ' 여자애 그냥 엎혀가 무것 안 함', '8'],
#  ['140693',
#   ' 연기 왜 따위 하는 잘하던 애니 만들었 이런 질 연기 봐 됐 장르 왜 코미디 빠져 어이 없어 여러 번 웃었 스릴러 액션 코미디 추가해',
#   '1'],
#  ['140693',
#   ' 확실히 재밌긴 했 로미 반 좀비 대체 하는 뭔 모르 주인공 도와줄 하면 보고 있고 좀 답답했 결말 솔직히 좀 김 빠지는 느낌',
#   '7'],
#  ['140693',
#   ' 좀비 영화 드라마 광 기대하고 봤 영화 긴장감 전혀 없었 워킹데드 드라마 편 정도 본 느낌 랄 까 주인공 총 하나로 좀비 때 잡 수 있다 무협 영화 아니',
#   '5'],
#  ['140693',
#   ' 원작 재미 요소 전부 빼고 흥미 끌 좀비 죽 이기 연출 하니 명작 망작 상업 영화 한국 일본 영화 산업 죽이',
#   '2'],
#  ['140693', ' 어설픈 내용 래서 아예 내용 뒷전 하고 액션 치중 했', '5'],
#  ['140693', ' 믿고 거르 일본 영화 노잼', '1'],
#  ['140693',
#   ' 영화 왜 이럼 특수 효과 빼면 도대체 뭘 보라 겁 갑자기 뜬금 없는 로맨스 부산 행 보고 좀 아쉽 생각 했 이 영화 정말 답 없 더 놀라운 사실 이영화 평점 점 것',
#   '1'],
#  ['140693', ' 좀비 고어 지루함 돌려 포기', '5'],
#  ['140693',
#   ' 진짜 감독 문제 듯 하다 좀 더 중하 만들었 좋 영화 됐 같은 너무 답닾 하게 만들었 어이 없게 만들었 멍하니 있는 장면 젤로 이상하다 감독 문제 영화',
#   '1'],
#  ['140693', ' 역시 일본 영화 유치 함 소름 끼 중 병 대사 등등 영화 망침 워킹데드 미국 좀비 영화 너무 완벽해서', '6'],
#  ['140693', ' 답답한 싫어하시 분 비추 주인공 하도 빡 대가리', '1'],
#  ['140693', ' 김인권 연기 잘합', '10'],
#  ['140693', ' 영화 역시 한국 이군', '1'],
#  ['140693', ' 초 중반 임팩트 아까 정도 후지산 가면 영화 말 그대로 산 감 디텔 고퀄', '6'],
#  ['140693', ' 와 잔인 하네 저 여고생 완전 짐짝 반 좀비 되 젤 쌔면', '8'],
#  ['140693', ' 만화책 보시 비슷하겠 하시 분 보시 정신 건강 더 좋 원작 모르 분 한번 보셔 되 개인 비추', '2'],
#  ['140693',
#   ' 거지같 은색 기 이 영화 까는 사람 전부 일본인 싫어 그러 임 공과 사 떠나서 영화로 평점 먹여 그 패배 조센징 소리 처 듣는 중요한 히로 미짱 귀여워 이뻐 이뻐',
#   '10'],
#  ['140693',
#   ' 역시 일본만화 영화 리메이크 항상 실망 만화 원작 자체 충분히 훌룡한데 뭐 만화 자체 만들었 영화로 만화 겨 넣으 항상 아쉬운',
#   '6'],
#  ['140693', ' 부산 행 최고 히어로 최고 둘 잼', '10'],
#  ['140693', ' 역시 니뽄 찌 영웅 되', '3'],
#  ['140693',
#   ' 잔 하지 용도 없고 시간 동안 계속 답답 사이다 도 없고 고구마 계속 먹은 여주 처음 대사 하지 변하고 나선 그냥 민폐 덩어리 임 돈 아깝 부산 행 걸 어케 비교하는 모르',
#   '1'],
#  ['140693', ' 초반 진짜 신선하고 재밌었 뒤 갈수록 일본 특유 뻔하고 지루한 영화 돼 버림', '6'],
#  ['140693', ' 평점 잘 남기는 만화 더 재밌었 만화 답답함 컷었는데', '10'],
#  ['140693',
#   ' 일단 일본 영화 답 더러운 장면 많아 무서운 아니 더러운 그런 그리 배우 어색한 연기 과장 된 연기 날쌔던 좀비 주인공 앞 늦어 양쪽 포위 됏 데 혼자 총 자루 해치',
#   '1'],
#  ['140693', ' 살아남 자가 강한 것', '7'],
#  ['140693',
#   ' 전개 부자연 면 있지 원작 만화 장면 살릴 노력한 보이 좀비 퀄리티 장난 아니 시각 효과 받 만하 과도 하드코어 전개 속 원작 만화 특유 풍자 사라진 같아 아쉽',
#   '8'],
#  ['140693', ' 재미없 아니 만화 버전 처럼 재미있지 않다', '5'],
#  ['140693', ' 그로테스크 재미 뒤 숨겨 단순 풍자 물', '8'],
#  ['140693', ' 재미있다 걸 됐', '10'],
#  ['140693', ' 만화 원작 영화로 엄청나게 만들었', '8'],
#  ['140693', ' 역대 좀비 영화인 듯 영화 굉장히 만화 스럽 싶었 역시 원작 만화 였', '8'],
#  ['140693', ' 주인공 암 덩어리 아니 괜찮 보는 짜증 났 암 유발 조심', '7'],
#  ['140693', ' 여고생 피곤하면 우리 집 자라 내 라면 더 끓여 먹 여주 할 뎅', '10'],
#  ['140693', ' 똥 싸다 끊은 느낌 영화 임 잔인 할 뿐 걸 보고 부산 행 보면 부산 행 얼마나 대단한 깨닫 됨', '1'],
#  ['140693',
#   ' 여고생 왜 멀쩡한 나오지 않고 만화 안보 보면 왜 그런 평생 모를 아마 후속 나올 싶은 볼 마음 없 너무 노잼 일본 특유 감성 엿 같았 영화',
#   '4'],
#  ['140693', ' 기대한 재밌지 않아 실망했', '2'],
#  ['140693', ' 좀비 액션 시퀀스 좋', '6'],
#  ['140693', ' 진짜 한국영 일본 영화 차 일본인 약빨 영화 만드는', '10'],
#  ['140693', ' 부산 행 다른 재미 있네', '6'],
#  ['140693', ' 남자 하나 여자 하나 어부바 하나', '9'],
#  ['140693', ' 우리나라 좀비 영화 굉장히 잘 만들었', '6'],
#  ['140693', ' 통쾌 건 있는 왜 좀비 다가오는', '7'],
#  ['140693', ' 영화 이런 영화', '1'],
#  ['140693', ' 좀비 행 태만 참신 함 내용 넘 진부 함 전형 일본 영화 평점 넘 높이 책정 되 평균 내리 점 줌', '1'],
#  ['140693', ' 하도 만들었 다해서 봤 좀비 물 안 본 일반인 설레 발 이었 지루하다 점 낮추기 위해 점준', '1'],
#  ['140693', ' 남 답답해서 개 짜증 나네', '1'],
#  ['140693',
#   ' 너무 허 접합 일관 없는 좀비 일본 특유 주인공 찌 함 부산 행 비교하시 솔직히 부산 행 좀비 일관 없어 그냥 둘 류 좀비 물 입니',
#   '5'],
#  ['140693', ' 일단 원작 만화 였 하면 옮기 기는 잘 옮겼 특수 효과 좀비 연기 괜찮 그럼 불구하고 재미있다 하겠', '7'],
#  ['140693',
#   ' 재미 있었 건 인정 정말 답 없게 유치 하다 어 말 유치 조악 스럽 잔인 긴장감 없고 개연 성도 없고 그냥 자기 땡기는 설정 여주 들이부었 고양이 여고생 교복 주종 관계 최종병기 답 없',
#   '3'],
#  ['140693', ' 부산 행보 특수 효과 넘사벽 대신 내용 부실 좀비 연기자 무려 한국인 보스 좀비 한국 셋트장 한국', '7'],
#  ['140693', ' 원작 만화 디테 일이 전혀 느껴지 않는 지루하다', '3'],
#  ['140693', ' 평점 왜 높냐 개 재미없', '6'],
#  ['140693', ' 로미 카와이 카와이', '10'],
#  ['140693', ' 평점 점 근처 일본 문화 싫다 안보 된 뭐라 뭐라 떠들 필요 없다 영화 자체 수작', '10'],
#  ['140693', ' 포켓몬 지우 엽총 후지산 등산 하는 스토리', '7'],
#  ['140693', ' 완전 시간 낭비 했 확실히 일본 이런 쪽 영화 만드는 재주 없는', '2'],
#  ['140693', ' 역대 좀비 영화 위 주후 위 아이엠 히어로', '10'],
#  ['140693', ' 보는 내내 주인공 김연우 생각남', '7'],
#  ['140693', ' 기대한 것 보다 모자란 영화', '5'],
#  ['140693',
#   ' 일본 사회 장기간 불황 침체 빠진 자국 구해 영웅 기다리 있는 아닐 아니 좀비 몽땅 죽여 버리 처음 리셋 싶',
#   '10'],
#  ['140693',
#   ' 일본 마블 히어로 원작 재밌게 봤 나로 선 성장 믿음 직 못 원작 주인공 설정 쪽 더 마음 든 영화 한정된 상영 시간 맞추고 제목 그 자체 더 의미 둔 같',
#   '8'],
#  ['140693', ' 직업병 얼마나 무서운 알려 영화', '8'],
#  ['140693', ' 부산 행 보다 낫다 하기 알바 냄새 하드코어 개뿔 사우나 안 모래시계 쳐다보 인내 보았 도', '3'],
#  ['140693',
#   ' 와 진짜 걸 재밌다 사람 있구 원작 있는 같은 원작 안보 영화 본 사람 태국 좀비 영화 이었 레알 마지막 주인공 시계 풀 총 쏘고 상황 정리할 때 게뭐 이영화 본 졸라 자괴 감 들었 수고하세 입 소문 믿 진짜 못 됨',
#   '1'],
#  ['140693', ' 일본 영화 진짜 만드는 주인공 암 걸리', '1'],
#  ['140693', ' 살 살 이런 기 영화 별로 없었 제작 회수 하려 한국 알바 풀어 뽑아 낼', '1'],
#  ['140693', ' 남 주인공 개 찐 따 옴', '6'],
#  ['140693', ' 히데 오 애인 좀비 변하는 전반 분 정도 나머지 살려 먹인 답답한 영화 였', '6'],
#  ['140693', ' 그런 원작 살렸 너무 터지는 비중 둬 스토리 좀 약하지 나가 사와 마사미 이제 물 갔', '10'],
#  ['140693', ' 원작 살리 못 굿', '10'],
#  ['140693', ' 시간 동안 끝 보면 초반 분 재밌었 죤나 노잼', '1'],
#  ['140693',
#   ' 갠적으루 잼 봤 로미 뭔가 미스터리 가나 올 같은 느낌 전개도 빠르 좀비 물 영화 왠만하면 무서워 이영화 좀비 소름 돋는',
#   '9'],
#  ['140693',
#   ' 코미디 살짝 있으 매우 하드코어 함 로미 같은 용병 너무 있어 실망 참 보면 계속 오정세 쿨 이재훈 생각나더',
#   '6'],
#  ['140693', ' 초반 분 이후 개 지루함 평점 알바 극혐', '1'],
#  ['140693',
#   ' 영화 보는 주인공 스즈키 히데 오라 이름 한자 영웅 설명 덧붙입니 마지막 그냥 히데 오 하죠 여기 주인공 모습 변했 확실히 알',
#   '9'],
#  ['140693', ' 소설 원작 이 딴거 그냥 좀비 영화 매니아 보세 매니아 좋아할 새벽 저주 약간 비슷하기 하고', '10'],
#  ['140693', ' 긍정 힘 믿음 배신 하는 순수한 인간 가능성', '8'],
#  ['140693', ' 음 조잡 하다 그냥 영상 퀄 박수 쳐 준 만들어 부산 행 괜찮 마지막 좀 흐지부지 하네', '6'],
#  ['140693', ' 원작 보고 본 더욱 재미있고 그냥 봐 충분히 재미있다', '8'],
#  ['140693', ' 연출 높게 사서 점 짜 원작 살려 씨 무슨 갑자기 부 죽 좀비 거대 몬스터 되냐 왜 간츠 만드냐', '6'],
#  ['140693', ' 부산 행 재미있진 않지 부산 행보 못 영화', '1'],
#  ['140693', ' 기대 컸 핵 실망 좀비 영화 제일 중요한 긴장감 긴박 감 하나 없다', '3'],
#  ['140693', ' 어이 를 찿게되 내 곧 스트래스 쓰러지 않 걱정 하게 된 어이 없고 답답하다', '4'],
#  ['140693', ' 핵 노잼 월드 워 부산 행 이런 생각하고 보면 큰 오산 구성 연출 앵글 쓰레기', '1'],
#  ['140693',
#   ' 이 뭐 좀비 영화 만들 싶었 본 게뭐 내 만들어 거 낫 긴장감 제로 스토리 제로 라이 걸 돈 주고 본 사람 있다 본 시간 아까 죽',
#   '1'],
#  ['140693', ' 그냥 볼 급 영화 로미 활약 적은 가장 아쉽 먼 보여 알 오네가', '8'],
#  ['140693',
#   ' 남자 주연 정말 평범한 일상 사는 평범한 외모 평범한 사람 마치 내 모습 보는 한 느낌 들었 그런 주인공 누군가 영웅 되는 모습 대리 만족 느끼 하네 마지막 모자 다시금 쓰는 모습 정말 멋졌',
#   '9'],
#  ['140693', ' 좀비 또 다른 방식 특색 있게 만들어 아이디어 좋 물론 영화 전체 만족스러운 편 아님', '8'],
#  ['140693', ' 프로포즈 작전 마사미 나와 보게 된 영화 기대 보면 볼 함', '8'],
#  ['140693', ' 후지산 아울렛 파크 나온 차 웬 한국 차가 많아 뭔가 했 한국 촬영 했', '10'],
#  ['140693', ' 로미 사랑해', '8'],
#  ['140693', ' 체 생 무섭', '8'],
#  ['140693', ' 솔직히 재미없', '2'],
#  ['140693',
#   ' 이 좀비 자아 없는 말 중얼거리 도망치는 긴장감 없고 연기 어설프 시간 낭비 유치 하다 진짜 봐 이건 새벽 저주 표절 잖아 표절 제대로 하던 도망가는 긴장감 없고 새벽 저주 여주 인공 반 만해',
#   '1'],
#  ['140693', ' 원작 어떨런 몰라 배우 연기 연출 짜증 유발', '5'],
#  ['140693', ' 역시 부산 행 초딩 만든 영화 수준 언론 빨 이란 걸 보 여준 작품', '10'],
#  ['140693', ' 이 부산 행보 재밌다 생각 그닥', '5'],
#  ['140693',
#   ' 글쎄요 원작 각색 일본만화 원작 영화 특유 유치 함 없는 같 이런 영화 탄탄 스토리 찾긴 어렵 부산 행 멀 그리 스토리 좋 차라리 특수 효과 액션 아이엠 히어로 손 들어주고 싶네 히데 오는 뽑은',
#   '9'],
#  ['140693', ' 다음 편 기대해 본', '7'],
#  ['140693', ' 명작 솔직히 인정할 인정하자', '10'],
#  ['140693', ' 일본 영화 뭔가 영화 만화 같은 느낌 나게 연출하고 연기한 그것 빼고 재밌었', '7'],
#  ['140693', ' 기대 너무 해서 런가 하드 하지 않고 재미있지 않고 기이 좀비 흥미로웠', '5'],
#  ['140693', ' 쪽바리 특유 질질 끄는 답답한 전개도 짜증 나고 로미 하드캐리 장면 부족하고 쫌 답답했', '6'],
#  ['140693', ' 이럴 로미 변신 시키 말 강하게 만들어 기대하게 만들어', '5'],
#  ['140693', ' 예상외 볼 조금 놀랐 일본 특유 좀비 영화 였 삼류삘 안', '7'],
#  ['140693', ' 별로 였 퓨', '3'],
#  ['140693', ' 지금 봐온 좀비 색다른 모습 좀비 인상', '7'],
#  ['140693', ' 여자친구 좀비 될 때 해도 와 이영화 간만 대작 싶었 거기 까지', '6'],
#  ['140693', ' 실사 된 일본 영화 별로 였 이 영화 볼 합', '7'],
#  ['140693', ' 점도 아깝 징 그럽 하고 초반 지루 그 자체 여자애 힘 센 마지막 앉아 있는 무것 안함 반전 도 없다', '1'],
#  ['140693', ' 좀비 영화 기대하고 보았 주인공 답답해서 보기 좋 액션씬 괜찮', '5'],
#  ['140693',
#   ' 오랜만 일본 영화 즐겁 본 같 이제 일본 영화 너무 만화 니 메이 션 따라 하면 망한 안 일 적당히 따르 말 이어 무척 보기 좋',
#   '10'],
#  ['140693',
#   ' 저 남친 땜 어쩔 봤 역시 초반 부 소리 지르 눈 가리 했 중반 부 사람 죽는 너무 비현실적 징 그러 오히려 볼 있게 되 먼 소리 중간 중간 빵빵 터지는 곳 있어 배꼽 잡고 웃다 덜덜 떨다 재밋 봤',
#   '9'],
#  ['140693',
#   ' 영화 부산 행보 재미있게 봤 가면 갈수록 스토리 이상한 쪽 빠져 들 결말 아쉽 다른 쪽 만들었 최고 좀비 몰 영화 되 않 합',
#   '8'],
#  ['140693',
#   ' 지금 헐리웃 좀비 영화 다를 바 없 단순하게 피 범벅 되는 좀비 영화 만들 부산 행 만들 아님 그냥 만화책 봐',
#   '4'],
#  ['140693', ' 부산 행 표절 영화 일본 표절 어디 까지', '2'],
#  ['140693', ' 나름 묘사 적절한 긴장감 다른 좀비 물 찾아볼 수 없었 케리 터 로미 재밋 봤 아쉬움 남은 영화', '9'],
#  ['140693', ' 그로테스크 이미지 끝 밀고 나간 뚝심 인정할 없다 중간 고양이 펀치 넉 다운 상태', '8'],
#  ['140693', ' 좀비 영화 일본 신선하지 일본 반감 있는 있는 관객 글쎄', '7'],
#  ['140693', ' 기존 있던 호러물 확실히 틀리 배우 연기 잘하고', '10'],
#  ['140693',
#   ' 부산 행 꽤 모방 걸 느낌 기생수 급 와 나가 사와 마 시미 아리 무 카스 미 미모 삭막 좀비 속 안식 주는 꽤 무서운 영화 탄 나올',
#   '10'],
#  ['140693', ' 재밌는 영화 본적 없다 최고다', '10'],
#  ['140693', ' 태국 일주일 간판 내린 영화 움', '1'],
#  ['140693', ' 원작 잘 살려 냈 뿐 아니 오오 이즈미 요 연기 빛 바랬', '8'],
#  ['140693',
#   ' 마지막 순간 여느 좀비 영화 몰려오는 수 없는 좀비 때 궁지 몰 린 소수 주인공 명 난 그 상황 설마 이런 전개 일 줄 감탄 말',
#   '8'],
#  ['140693', ' 볼 함 호루루 루를루 루루 룰', '5'],
#  ['140693', ' 그냥 간단하게 말하자 찌개 먹었 뭔가 빠진 같고 부족한 느낌 같', '6'],
#  ['140693', ' 편 생각 안 편 몰 빵 쳤 초대 박 히로 미가 막판 죽여줬 난 편 볼 마사미 진리 입니', '10'],
#  ['140693',
#   ' 일본만화 원작 국가 별 좀비 비슷하지 나름 독특한 좀비 내용 큰 차별 없지 일본만화 느낌 나네 잔인 하긴 나름 재미있게 봤',
#   '8'],
#  ['140693', ' 좀비 퀄리티 굿 예고편 충분하다', '7'],
#  ['140693', ' 읭 하고 끝나긴 재미나 봤', '9'],
#  ['140693', ' 너무 많 쑤셔 넣으 했 임팩트 충분', '9'],
#  ['140693', ' 재밌게 봤 영화 재미없 여주 인공 이뻐 좋', '6'],
#  ['140693',
#   ' 원작 내용 충실 것 매우 만족했 다만 그 많은 내용 겨우 시간 내외 압축 시켜 보니 작가 전달하려 내용 많은 빠진 같아 아쉽',
#   '9'],
#  ['140693', ' 스즈키 히데 오 멋있다', '8'],
#  ['140693', ' 생각 잔 않고 좀비 영화 클리 세 너무 국한 됨', '6'],
#  ['140693',
#   ' 뎃코 보다 기절 하는 여태 봤 좀비 차원 달랐음 뒤 갈수록 잔인 지는 저 뎃코 때문 무난 하게 느껴짐 여 튼 거 보고 뎃코 잔 상이 오래 가서 잘 때 불 끄 기 힘들었 일본 특 유의 공포 있는 영화',
#   '8'],
#  ['140693', ' 너무 재미있었 진짜 역대 좀비 아니었 싶', '10'],
#  ['140693',
#   ' 결말 조금 아쉽 전체 재밌었 역시 좀비 영화 답 총 쏘고 머리 날 라가 피철철 나고 오랜만 영화관 보아 좋 영화관 단 개 아쉽',
#   '8'],
#  ['140693',
#   ' 영화 보면 나가고 싶 생각 해본 적 없는 온몸 베베 꼬면 볼 정도 나가고 싶었 진짜 미친 것 같다 만화책 원작 것 이제 알 평점 높은 사람 만화책 빠져 나오는 잔인 거 볼게 없다 내용 기 노잼',
#   '1'],
#  ['140693',
#   ' 일본 영화 스타일 좋 하는 이 영화 재미있 좀비 영화 좋아하면 볼 함 이 영화 맘 든 일본 영화 특유 오글거림 없어 좋 상영 하는 곳 찾기 힘든 영화',
#   '8'],
#  ['140693', ' 구매 전쟁 빚어 아울렛 생사 전쟁 벌어지는 게 흥미롭', '7'],
#  ['140693', ' 나 그래 히로 미가 싸울 뜻 하더 그게 아니', '10'],
#  ['140693',
#   ' 막판 잔인함 속이 시원한 잔인함 였 불쾌 하진 않았 평점 점 주면 평 쓰시 분 일본 대한 개인 감정 때문 아닐 하는 생각 들 정도 터 무니 없어 보이 일본 특유 정서 잘 담아 낸 좀비 물 봤',
#   '9'],
#  ['140693', ' 이 왜 평점 점 댄 이해 안 간다', '1'],
#  ['140693', ' 잔인 하드코어 영화 진정 좀비 영화', '8'],
#  ['140693', ' 우리 집 강아지 똥 싸는 더 스릴 있고 재밌다', '1'],
#  ['140693', ' 상상 이상 실감 나고 재밓 봤 결말 아쉽 완전 재미있어', '10'],
#  ['140693', ' 게 무슨 좀비 영화 진짜 좀비 물 최고 좋아하는 여지 껏 본 중 제일 잔인 제일 별로 정말 돈 아깝', '1'],
#  ['140693', ' 새로운 좀비 참신 맛 있 몰입도 좋 전체 보면 평이 수준 입니', '8'],
#  ['140693', ' 나 재밌게 봤 보석 발견한 기분', '9'],
#  ['140693', ' 워킹데드 짝퉁 재미 짝퉁 노잼 돈 아깝', '4'],
#  ['140693',
#   ' 다른 좀비 물의 좀비 개성 있고 유머 러스 하면 서도 기괴함 느껴져 좋 징글징글 좀비 게임 매니아 라면 강추 합',
#   '10'],
#  ['140693',
#   ' 리얼 좀비 일본 영화 주온 필터 필터 존재하는 밝은 곳 보나 어 두운 곳 보나 음산 시시 느낌 주인공 어수룩함 승화 시킴 심지어 숲 나무 봐 가 아니 어 뭐 제발 부산 행 비교하지 말',
#   '10'],
#  ['140693',
#   ' 역대 좀비 영화 최악 주인공 찌 함 절정 보여 줌 여주 인공 암 덩어리 존재 계속 잠 쳐 잠 중반 부 쇼핑 센터 같은 곳 싸우는 비 비탄 총가 지고 싸움 대사 이런 소용없 중반 부 최대 생 좀비 갑 주인공 더 멋있',
#   '1'],
#  ['140693', ' 나름 괜찮 원작 잘 살렸 부산 행 비하면 뭐 대단하지', '8'],
#  ['140693',
#   ' 좀비 물 좋아하고 부산 행보 재밌다 후기 보고 봤 정도 아니 그냥 집 봤 만족할 수준 영화 중간 중간 너무 지루하고 답답하고 마지막 쫌 시원한 느낌',
#   '7'],
#  ['140693', ' 그냥 고어 높이뛰기 때문 세수 못하겟', '6'],
#  ['140693',
#   ' 개인 기대 않고 봤 정말 재밌게 봤 깔끔한 스토리 선택 집중 잘해서 필요한 부분 잘 보여 재미 챙겼 다만 원작 본 사람 너무 잘랐 덧 히로 미가 왜 무것 하지 않냐 아직 원작 반도 따라가서 그런',
#   '10'],
#  ['140693',
#   ' 연출 좋 내용 조금 루즈 지겨운 느낌 들었 사건 사람 간의 유 대감 생각 표현한 조금 임팩트 강한 적어 조금 지루하게 본 편 존비 징 그럽 해서 걱정했 생각 괜찮 무섭 않았',
#   '6'],
#  ['140693',
#   ' 은근 초반 무섭 아내 나온 사람 그 후 무난 라스트 자기 믿어 준 사람 위해서 혼신 힘 바쳐 히어로 되 그냥 냥 볼 함',
#   '8'],
#  ['140693',
#   ' 일본 스러운 잔인함 다른 좀비 물 독특해서 좋 약간 지능 있는 좀비 같은 느낌 스토리 허 술 제일 쎈 여고생 왜 무것 하지 않 잠 자고 그럴 아예 배역 다르 하거 넣질 말 스토리 엉망',
#   '7'],
#  ['140693', ' 일본 영화 극장 처음 봤 영화 퀄리티 너무 좋', '10'],
#  ['140693', ' 택시 타기 전 최고 여고생 나온 후 하품 좀비 개성 있다 좋', '1'],
#  ['140693', ' 좀비 매우 실감 남', '7'],
#  ['140693',
#   ' 일본 영화 발전 부산 행 보다 재밌다 일본 고유 고어 물이 짙은 영화 다만 일본 영화 고유 잔잔 함 다소 지루함',
#   '8'],
#  ['140693', ' 징 그럽 재밌었', '8'],
#  ['140693',
#   ' 청불 모르 따라가서 봤 춤추면 나왔 진짜 부산 행 애교 였 로미 너무 기대 했 아쉽 했 최근 본 영화 너무 재밌게 봤',
#   '10'],
#  ['140693',
#   ' 동양 좀비 영화 좀비 퀄리티 가장 훌륭합 다만 영화 자체 일본 의 정서 담겨 때문 감안 하셔 할 하네 좀비 물리 친 보다 주인공 내적 변화 성장 포커스 맞추고 보시 재밌',
#   '9'],
#  ['140693', ' 좀비 영화 좋아하는 인 정말 재밌게 봤 편도 기대되', '10'],
#  ['140693', ' 일본 영화 만화 원작 된 영화 절대로 안 볼 친구 말 믿고 평점 점도 안 되 본 내 바보 같다', '4'],
#  ['140693',
#   ' 좀비 나와 지루해 약간 코미디 같은 좀비 웃기 생김 뚱뚱한 좀비 나올 때 개 웃겼 로미 뭐임 왜 자기 하니 뭔가 부족해',
#   '6'],
#  ['140693', ' 볼 만 합 멜빵 바지 입은 애가 압권', '7'],
#  ['140693', '', '8'],
#  ['140693', ' 일본 영화 편견 가지 안보 시지 마세 재미있어', '10'],
#  ['140693',
#   ' 부산 행 배는 더 재밌는 잔 잔인 거 싫어하는 내 볼 정도 아니었 징 그럽 잔인 거 많 중간 늘어지는 느낌 나름 좀비 물 괜찮 봤 무비 나이트로 천원 주고 볼 합',
#   '7'],
#  ['140693',
#   ' 일본 그냥 좋아하진 않지 이영화 좀 좀비 영화 신선했 좀비 영화 역사 다시 쓴 느낌 이영화 부산 행 비교하자 우리나라 아직 좀 밍밍 하다',
#   '10'],
#  ['140693', ' 참 드럽 재미없 촌빨 날리는 영화', '4'],
#  ['140693', ' 이건 좀비 영화 생각 들 그거 무지막지 놈 싸우는 일본 특 유의 고어 물이 생각 강하게 드는 영화', '7'],
#  ['140693',
#   ' 초반 주인공 여친 좀비 씬 보고 앞 남은 시간 동안 어떻 버티 란 생각 들었 너무 무서움 좀비 매니 게젤 무서웠 허리 꺾임 같은 이 진짜 좀비 구나 싶 정도 무서움 따지 부산 행 어린이 수준 임 비 비탄 냥 펀치 때메 점 깜',
#   '8'],
#  ['140693', ' 로미 예쁘 끝', '10'],
#  ['140693', ' 잔인 거 빼면 볼게 없네', '6'],
#  ['140693', ' 히키코모리 비약 발전 그린 감동 좀비 영화', '10'],
#  ['140693', ' 좀비 활용해야 답답혔 오히려 도시 박진 감 고재 밋었 음', '1'],
#  ['140693', ' 좀비 물이 보더 코믹 물', '6'],
#  ['140693',
#   ' 살 살 이런 최악 영화 처음 듯 합 이런 영화 기대 했 사치 어떻 영화 별반 주는 아깝 들었 재미없 소리 말 사치 만드는 영화 입니',
#   '1'],
#  ['140693', ' 기행 종 좀비 최고다', '10'],
#  ['140693', ' 멀리뛰기 좀비 강렬하게 무섭', '9'],
#  ['140693', ' 부산 행 재미있다', '9'],
#  ['140693', ' 봐 열 준', '10'],
#  ['140693', ' 레얄꿀잼 부산 행 비교 불가', '10'],
#  ['140693', ' 기대했 실망 큼 보는 내내 주인공 개 여주 인공 뭔가 반전 있 알 그런 없었 갈수록 영화 좀 이상했', '3'],
#  ['140693', ' 원숭이 영화 원숭이 영화', '1'],
#  ['140693', ' 믿고 거르 일본 실사 영화', '1'],
#  ['140693', ' 징 그럽 잔 웃긴 그냥 일본만화 상영 관 없다 너무 하네', '7'],
#  ['140693', ' 노잼 너무 노잼 주인공 육상 선수', '1'],
#  ['140693',
#   ' 원작 모르 남자 총 어쩌고 하는 무식 평론가 무지 함 날릴 만큼 볼 영화 원작 몇몇 캐릭터 조금 다르 때문 원작 비교 해서 보길 추천',
#   '7'],
#  ['140693',
#   ' 만화가 원작 런가 좀비 물 스토리 구성 탄탄 함 다양한 좀비 들보 재미 잇고 일본 특 유의 하드코어 잔인함 볼 편도 나와',
#   '9'],
#  ['140693', ' 이건 진짜 아님 일단 돈 주고 걸 본 내 또 다른 피해자 나오지 않길 바람 보자 긴 동생 끄 댕 잡음', '1'],
#  ['140693',
#   ' 평점 낮아 볼까 고민 했 만화책 재밌게 읽었 영화 봄 약간 스킵 되 바뀐 스토리 있긴 재밌었 스토리 만화 아직 치면 초반 부라 도 나올 같다 생각 드는',
#   '10'],
#  ['140693',
#   ' 초반 엄청났 후반 부 아쉬운 부분 많았 근대 남 주인공 모자 쓰 있 때 왜 자꾸만 김진표 가 생각 나 나 그런 생각 들었 싶',
#   '7'],
#  ['140693', ' 한 남자 현재 젊은이 성장기 카스 미 너무 이쁘', '7'],
#  ['140693',
#   ' 비위 약한 분 보기 힘드실 있겠 전 여태 봤 좀비 영화 중 최고 였 인상 깊은 장면 많네 로미 활약 약간 아쉬 뿐',
#   '10'],
#  ['140693', ' 개인 재밌었 감동 없고 스릴 가득', '10'],
#  ['140693', ' 볼 하네 볼 합', '9'],
#  ['140693', ' 원작 최대한 참고해서 제작 하셧 음 나쁘 않아', '10'],
#  ['140693',
#   ' 금 건 좀비 영화 잔인 게 당연한 잔 뭐라하는 사람 좀비 물 처음 본 분 잔인함 있기 이전 히데 오 성장 돋보였 생각합 로미 원작 잘 안 싸웠 긴 내용 단편영화 잘 각색 했',
#   '9'],
#  ['140693', ' 솔 찍히 부산 행 보다 훨 만들었 꿀잼', '10'],
#  ['140693', ' 호불호 극악 갈림 아마 평점 과 점 싸움 전 점 입니 마지막 와 아니 저걸 와 이 소리 나옴', '10'],
#  ['140693', ' 결말 무것 없 만화 보는 나 그냥 볼 수준 결말 개 무것 없어 허무 화난', '5'],
#  ['140693', ' 일본 영화 싫어하는 재밌게 본 첫 일본 영화 혼자 조조 봤 초반 좀비 분장 때메 너므 무서웠', '10'],
#  ['140693', ' 돈 아깝 시원하게 봤', '9'],
#  ['140693', ' 오랜만 좀비 물 다운 영화 봤', '10'],
#  ['140693', ' 제목 그대로 주인공 빛 났 영화인 것 같', '10'],
#  ['140693',
#   ' 부산 행 재밌게 보고 일본 하드코어 좀비 물이 길 흥미 생겨 봤 기대 이하 이야기 전개 비교 안된 아마 원작 만화 전개 거의 그대로 가져와 그런 개성 좀비 보는 재미 있다 시원한 액션 주인공 각성 하는 마지막 부분',
#   '6'],
#  ['140693',
#   ' 혼자 보러 갔 간혹 실눈 뜨 봤 영화 파주 아울렛 찍었 분장 울 분장 미용 대학생 참여했 전체 재밌었 질질 짜는 신파 없고 뻔하다 요소 제거해서 담 게 좋',
#   '8'],
#  ['140693',
#   ' 처음 평점 쓰는 점도 아까 움 내용 하나 없고 잔인 징 그럽 한 영화 로미 구해 줬 마지막 뭐 하나 할 줄 알 끝 짐 되 도대체 왜 주인공 결말 궁금해서 앉아 차 타고 나가는 끝 재미없 짜증 남',
#   '1'],
#  ['140693', ' 잔인 좀비 세상 찌 주인공 살아남', '10'],
#  ['140693', ' 원작 봤 재밌었', '9'],
#  ['140693', ' 좀비 물 역시 청 불 마지막 로미 뭔가 기대 했', '7'],
#  ['140693', ' 살짝 지루한 감 있었 좀비 너무 무서웠 그리 고저 이영화 보고 헌혈 하러 갔', '7'],
#  ['140693', ' 지겨워 죽는 줄', '4'],
#  ['140693', ' 정말 재미있게 봤 스토리 흐지부지 끝나지 않고 처음 끝 긴장하면 봤 좀비 영화 좋아하시 분 괜찮 할', '10'],
#  ['140693', ' 일본 좀비 물 너무 무서웠', '10'],
#  ['140693',
#   ' 좀비 영화 중 월드워즈 비슷할 정도 재밌 극장 보 추천합 다만 아쉬운 잠 자 빠져 여고생 쓸데없 이야기 너무 넣었 그 부분 빼고 고어 좀 더 넣었 하는 아쉬움 많 좀비 정말 잘 만들었',
#   '7'],
#  ['140693',
#   ' 좀비 영화 만 생각하면 손색 추천 원작 좋아했 사람 조금 아쉬 수도 영화 특성 많은 것 잘라 각색 내용 음 좀비 영화 좋아하는 사람 추천 킬링타임 굿 비위 약한 사람',
#   '6'],
#  ['140693', ' 재밌게 봤 여주 인공 너무 이뻐', '10'],
#  ['140693',
#   ' 아저씨 의 일본 오타쿠 판 영웅 되어 누군가 지키 싶어 평균 이하 사내 소망 좀비 영화 형태 표현 수작 아니 일본 영화 특유 마니 악한 부분 적었 좀비 묘사 준수 볼 했',
#   '6'],
#  ['140693', ' 로미 사이다 씬 보여 한 아쉽 재밌었 영화', '10'],
#  ['140693',
#   ' 뎃코 뜀 박질 좀비 기억 이안 난 영화 첨부 터 잔잔 하다 정점 흥분하며 최고 가야 이 영화 그러한 긴장감 좀비 묘사 집중한 것 같다 뭔가 두서 없고 결말 해결하려 서두름 보여 분후 지루했',
#   '2'],
#  ['140693', ' 진짜 재밌 넘 재밌 아주 재밌', '10'],
#  ['140693', ' 일본 표현할 있는 좀 더 하드코어 했 하는 바램 화끈 시원해서 좋 질질 짜는 부산 행 비교 불가', '8'],
#  ['140693', ' 옆 계속 핸드폰 봐 전혀 화가 나지 않았 영화', '1'],
#  ['140693', ' 은근 재밌어 너무 징 그러 장면 봤 상당히 독특하고 재밌게 보았', '8'],
#  ['140693', ' 역시 좀비 영화 잔인 해야 됨 거 보고 나 부산 행 덜 잔인 그냥 쓰레기 보임', '10'],
#  ['140693',
#   ' 그냥 그럼 이야기 연개 매우 떨어짐 좀비 잘만 듬 아수라 보다 평점 높은 이해 가안 가네 로미 머냐 애물 단지 이야기 해석 표현 부족함',
#   '7'],
#  ['140693', ' 캐비넷 속 상상할 때 히데 오 제 모습 보 여러 번 뿜었네 윽 나도 이제 캐비넷 나가 봐 할', '8'],
#  ['140693', ' 엽기 웃음 나 영화 였', '7'],
#  ['140693', ' 그냥 오락 물 일후 같은 진지함 없', '5'],
#  ['140693', ' 거 보고 여자친구 마마 눈 안보 했 맞 뻔 유치 재미 짐', '8'],
#  ['140693', ' 생각 재미있네 유머 장면 인해 호감 도 올라갔', '9'],
#  ['140693', ' 아이 엠 어 히어로 부산 행', '9'],
#  ['140693', ' 좋 소재 너무나 지루하게 뿌려 대는 대단하게 느껴질 뿐 이', '3'],
# ...
#   '1'],
#  ['140693', ' 노잼 잔인 오글 뻔함 깜놀', '2'],
#  ['140693',
#   ' 별 높으 신분 알바 중간 중간 일본 오글거리는 장면 참 거슬리 본 사람 알 겁니 좀비 분장 빼 뭔가 일본 영화 는걸 영화관 사람 끝나고 어리둥절',
#   '1'],
#  ['140693', ' 아수라 잼', '9'],
#  ['140693', ' 역대 좀비 영화 중 벌루 였', '4'],
#  ['140693', ' 초반 분 끝났 점 줬 여자친구 나오는 장면 영화관 뛰 쳐 나오고', '7'],
#  ['140693', ' 솔직히 거 각 나 진짜 핵꿀잼 봄', '10'],
#  ['140693', ' 전형 일본 스타일 영화', '8'],
#  ['140693', ' 좀비 아까운 영화 스토리 너무 지루하다', '1'],
#  ['140693', ' 원작 완결 안나 허무 하게 끝낫 재밋 잘만 영화 생각함 시계 고급 진 롤렉스', '8'],
#  ['140693',
#   ' 근래 본 영화 손꼽 망작 초반 하드코어 좀비 대란 좋 초 중반 루즈 해지 전개 캐릭터 개연 부족 막판 인간 쓰레기 희생 말 안되는 감정이입 로미 캐릭터 대해 선 설명 없다 너무나 불친절 하다',
#   '2'],
#  ['140693',
#   ' 뭔가 스토리 탄탄 하진 않지 나름 재미있게 봤 중간 중간 웃기는 장면 있고 끝 제대로 끝난 건진 잘 모르 시리즈 였',
#   '9'],
#  ['140693', ' 한동근 신 스틸 러', '7'],
#  ['140693', ' 만화책 극히 일부분 다뤘 볼 수 있 따 일본 좀비 왜 기 괴한 건가 주온 같아', '6'],
#  ['140693', ' 영화관 본 영화 중 클로버필드 다음 쓰레기', '1'],
#  ['140693',
#   ' 내 원래 영화 본 후 평점 남기는 사람 아닌 이건 진짜 나 다른사람 돈 낭비 시간 낭비 할 바 적 인생 쓰레기 영화 절대 보지 마세 제발',
#   '1'],
#  ['140693', ' 리얼 좀비 매니아 위한 정통 좀비 물', '8'],
#  ['140693',
#   ' 정말 밑 끝 없는 기분 더러워지는 영화 플렉스 관 봤 걸왜 돈 주고 일본 정서 맞아 런가 나 럼 나만쓰레긴 대 중 후 반 비추던 집니',
#   '1'],
#  ['140693', ' 재밌는 평점 왜 이러', '10'],
#  ['140693', ' 기대 너무 했 예고편 였', '4'],
#  ['140693', ' 나오는 모든 인물 전부 답답함 막 완전 재미없 않은 애매 느낌', '5'],
#  ['140693',
#   ' 평점 조절 하겟음 좀비 매니아 로써 괜찮 작품 생각함 초반 부 도시씬 진짜 역대 임 중후 반부 약간 처지 긴 하는 점 정도 된 생각함',
#   '10'],
#  ['140693', ' 너무 너무 재미있네', '8'],
#  ['140693', ' 소재 급 만듦 새는 급', '5'],
#  ['140693',
#   ' 좀비 정말 리얼 하게 잘 해 스토리 도대체 왜 이런 시작 결론 스토리 없 바이러스 왜 생겼 모르 로미 왜 다른 조큔 다른 주인공 히로 미가 후지산 간 건지 등등 주인공 성장 보여 건가',
#   '5'],
#  ['140693',
#   ' 확실히 좀비 좀비 답 표현했 로미 존나 답답 계속 멍 때리 잇기 바이러스 왜 시작된 후반 부 마무리 존나 허 접 뭐 이',
#   '3'],
#  ['140693', ' 진짜 개연 도 없 스토리 후짐', '3'],
#  ['140693', ' 급 시작해 급 끝나다', '6'],
#  ['140693', ' 로 본 것 나 신의 한수 완전 미친 여친 도시 택시 마지막 학살씬', '9'],
#  ['140693',
#   ' 좀비 영화 감동 필수요소 좀비 영화 라면 먼저 잔인 해야 볼맛 나지 멍 청아 일본 한국 안된 실사영화 라면 모를 설마 다른 부문 포함 시킨 아니 애니메이션 게임 캐릭터 한국 일본 졷 발리는',
#   '10'],
#  ['140693', ' 택시 타기 물론 재밌었 뒤 도 여주보 맛 재밌게 볼 역시 좀비 물 고어 해야 재맛', '10'],
#  ['140693', ' 부산 행보 재밌 솔직히 좀비 물 성인 등급 받아 됨', '8'],
#  ['140693',
#   ' 만화 너무 너무 재미있게 보았 영화 원작 가깝 잘 만들었 솔직히 부산 행 개봉관 늘려 보지 않았 싶은 아직 만화가 끝난 부 부정 나올 왜 결말 이상하냐 분 많은 아직 끝났',
#   '10'],
#  ['140693',
#   ' 원작 묶여서 해결 안된 된 부분 조금 있었 크리 쳐 영화 로써 강약 조절 훌륭했 생각된 마지막 클 막스 카타르 시스 느낄 수 있어 좋 원작 발목 잡혀 영화 조금 불친절 했 점 감점 요인',
#   '9'],
#  ['140693',
#   ' 역시 일본 영화 다운 밑 끝 없고 잔인 징 그러 스트레스 풀리 기는 하는 로 봤 그냥 일반 봤 될 법 영화',
#   '7'],
#  ['140693', ' 개 재밌는 중반 부가 살짝 별로', '8'],
#  ['140693', ' 유치 부산 행보 이 영화 만배 더 낫', '10'],
#  ['140693', ' 아저씨 후지산 행 맞죠 어 왜 갑자기 유턴', '5'],
#  ['140693', ' 부산 행 비슷한 스토리 무섭 잔인 웃김 결말 허무 로미 비밀 풀리 않은 채 끝나서 가 나올삘', '8'],
#  ['140693', ' 재미 남 시간 금방 갑', '10'],
#  ['140693', ' 하드코어 좀비 물 난 한일 수록 재밌더', '10'],
#  ['140693',
#   ' 그냥 유튜브 피 튀기 고기 패 걸 보는 게 정신 건강 좋 일본 놈 전쟁 때 그러 이런 잔인함 익숙한 생각 필요 없는 영화',
#   '3'],
#  ['140693', ' 비위 약해서 시작 분만 나왔 나와 매운 오뎅 국물 먹었', '3'],
#  ['140693',
#   ' 지금 영화 보는 중 남긴 부산 행보 더 재미없 좀비 영화 여기 필요없 장면 영화 시간 채우고 여 튼 핵 노잼',
#   '1'],
#  ['140693',
#   ' 좀비 물 좋아해서 기대 컸 몰라 생각 별로 일단 원작 봐 모르 그 로미 여고생 도대체 왜 반 좀비 된 모르 스토리 개연 부족한 느낌 좀비 좀 리얼 좋 했 지루했 차라리 부산 행 나',
#   '6'],
#  ['140693',
#   ' 주인공 말 안되 상황 판단력 느림 결말 똥 싸다 말 만화 본 친구 말 듣기 론 만화 절반 안되는 정도 분량 좀비 분장 잔인 걸 좋아하는 사람 라면 충분히 좋아할 예상합 일본 흥 하면 후속 나올',
#   '6'],
#  ['140693',
#   ' 스토리 중간 지루하긴 좀비 가장 잘 드러내준 좀비 영화 같고 내 가본 좀비 영화 중원 탑 금 어울리 잔인 좋 좀비 코미디 같 호불호 갈릴 수 있겠 만나는 너무 재밌게 봄',
#   '10'],
#  ['140693', ' 로미 이뿌 부산 행 능가 한 할 순 없지 부족하지 않다 조금 잔인 게 흠 랄 까', '8'],
#  ['140693', ' 징 그러 움 잔인함 케빈 인더 우드 영화 생각남', '2'],
#  ['140693', ' 부산 행 그냥 커피 이건 티 오피 이 잼 미 없으 좀비 물 왜 보나 멜로 봐', '10'],
#  ['140693', ' 부산 행 그냥 커피 이건 티 오피 이 잼 미 없으 좀비 물 왜 보나 멜로 봐', '10'],
#  ['140693', ' 부산 행 볼 함', '6'],
#  ['140693', ' 재밌어 생각 웃', '10'],
#  ['140693',
#   ' 지금 봤 좀비 영화 중 감히 최고 말할 수 있다 제일 잔인 했 영화 였 난 도중 감동 받은 장면 있어 눈물 흘렸 정도 스토리 괜찮 후속작 나왔 정말 좋',
#   '9'],
#  ['140693',
#   ' 초반 정말 괜찮 중반 갑자기 서부 영화 음악 나오면 이상해 짐 참고 진짜 좀비 대박 입니 비쥬 얼 깡패 임 팅 레딧 스페셜 메이크업 팀 모두 한국인 요 좀비 영화 즐겨 보는 짱 입니 잔인 거 좋아하시 분 보세',
#   '6'],
#  ['140693', ' 간만 괜찮 일본 영화 나왔 일본 특유 고어 스러 움 잘 표현한 듯 일단 원작 안 본 사람 만족', '9'],
#  ['140693',
#   ' 어제 보고 옴 진짜 재밋음 만화 안보 영화 봣 데 재밋어 오늘 만화 지금 나온 곳 까지 찾아 봄 꼭보 세영 잼 씀',
#   '10'],
#  ['140693', ' 히데 오 오정세 닮았', '10'],
#  ['140693', ' 마동석 가고 히데 오가 왔', '8'],
#  ['140693', ' 히데 오 변희봉 김연우 느낀 나 없었', '9'],
#  ['140693', ' 평이 좋 기대 봤 신선하다 볼 만하', '9'],
#  ['140693', ' 끝내네 감독 영화 뭔가 하다 가마 작품 전문 같네', '5'],
#  ['140693',
#   ' 현실 좀비 묘사 그 안 투영 된 흙 수저 삶 사회 성찰 병맛 급 문화 적절하게 담아 낸 요 근래 본 좀비 물 중 최고',
#   '10'],
#  ['140693', ' 난 괜찮 보고 왔 조금 어색한 부분 있고 급전 있었 괜찮 점 아니 점 점 준', '10'],
#  ['140693',
#   ' 좀비 스토리 이제 비슷 비슷하다 다만 젠 얼마나 더 리얼 가 그런 부산 행 차원 다르 허 조금 맘 걸리는 부분 몇개 있다',
#   '7'],
#  ['140693', ' 유머 코드 일본 스러 움 일본드라마 영화 보는 사람 괜찮 좀비 더 잔 부산 행 스 피디 하지 않아', '8'],
#  ['140693', ' 잔인 거 좋아하는 나 아주 만족 또 보고', '10'],
#  ['140693', ' 평점 리기', '9'],
#  ['140693', ' 포스터 간지 나서 점 줍니', '1'],
#  ['140693',
#   ' 평점 보고 안 봤 후회할 뻔 잔인 거 못 보면 평점 깎는 이해하지 일본 영화 무작정 까는 사람 반성했 좋 난 원래 일본 나 액션 영화 급 냄새 나서 꺼리는 편 이건 연출 각본 연기 우려 했 특수 효과 괜찮',
#   '9'],
#  ['140693', ' 부산 행 좀비 하나 무섭 마동석 젤 무서운 여기 좀비 보다 계속 깜짝 놀 게 하고 무섭 더 재밌다', '10'],
#  ['140693',
#   ' 영화 솔직히 초반 도시 좀비 나타난 좋 로미 년 한번 좀비 싸우고 짐 완전 마지막 뭐라도 할 알 암것 도안 중간 중간 너무 너무 지겨 웟',
#   '1'],
#  ['140693', ' 적나라 묘사 압도 박력 좀비 물 이래', '10'],
#  ['140693', ' 일드 파견 품격 나왔 정준하 닮은 배우 남 벙찐 표정 오마에 오 오마에 할 때 진짜 웃겼', '8'],
#  ['140693', ' 굳이 까지 만들었 했 일본 특유 공포 느낌 섞', '7'],
#  ['140693',
#   ' 구로 만화 기반 영화 라지 배경 지식 없는 나 있어 뜬금 없는 좀비 출연 정체 불명 여고생 등장 황당 했 중반 이 후 늘어지는 줄거리 예산 급 좀비 영화 로서 한계 자극 화면 자 잘한 개그 돌파 하려 거 같은 영화 였',
#   '6'],
#  ['140693', ' 병맛 재밌다 재미 볼 함', '7'],
#  ['140693', ' 코믹 하기 하고 일본 느낌 물씬 로미 미모 열일', '8'],
#  ['140693', ' 좀비 기발 함 인간 선 악 보다 부산 행 좀비 무것 아니었', '9'],
#  ['140693', ' 모시 모시 눈 이안 보여', '1'],
#  ['140693',
#   ' 우선 여주 넘 이쁘 평점 낮아 기대 안 의외 였 영화 죠큔 좀비 의 표현 소름 끼 칠정 였 스토리 나쁘 않았 몰입 감 잘 봤',
#   '10'],
#  ['140693', ' 본 좀비 물 최악 스토리', '1'],
#  ['140693', ' 이용철 재미없 영화 무조건 재밌다 이건 진리', '10'],
#  ['140693',
#   ' 오프닝 멋지 좀비 디테일 예술 였 시가지 전 벗어 난후 지루해 짐 아쉽 막판 총알 숫자 아쉽 남 계속 보니 류승룡 닮았',
#   '8'],
#  ['140693', ' 귀신 사람 겁 주기 하지 이 영화 일본 귀신 사람 쫓아 다니 물어 뜯는 더 무섭', '9'],
#  ['140693', ' 평점 적어 스포 하고 난리', '9'],
#  ['140693', ' 평점 신경 쓰 마시 꼭 영화관 가서 보세 후회하지 않', '8'],
#  ['140693', ' 좀비 본 볼 만하 스토리 그닥', '4'],
#  ['140693', ' 보면 욕 먹기 조 영화 여친 썸녀 하고 보고 쏠 로 돌아와', '5'],
#  ['140693', ' 진짜 보면 후회함 무슨 떡밥 풀 회수 안함 여자 마네킹 핵 노잼', '1'],
#  ['140693',
#   ' 부산 행 감동 코드 한국 좀비 아이엠 어 히어로 무제한 엽기 일본 좀비 또한 워킹데드 완성 높은 미국 좀비 새벽 황당 저주 블랙코미디 영국 좀비 골라 보는 재미 각 나라 특색 잘 살 좋',
#   '9'],
#  ['140693', ' 디테 일한 효과음 배경음악 히로 미가 원작 넘어서게 해줬', '10'],
#  ['140693', ' 정말 재밌게 봤 결말 쓰레기 같아 점 깜', '9'],
#  ['140693',
#   ' 만화책 본 사람 재미없 난 쩔게 재밌게 봄 아쉬운 원작 차로 쇼핑몰 탈출하면 총 질 장면 쩌는데 그게 나옴',
#   '10'],
#  ['140693', ' 비위 약하면 돼 진짜 오줌 비우고 관람 하자', '10'],
#  ['140693', ' 거 그 가 거', '1'],
#  ['140693', ' 나름 재밌게 봤 영화', '7'],
#  ['140693',
#   ' 흠 잔인 좋 했 내용 전개 방식 너무 일본 영화 스러워 그런 스타일 좋아하는 사람 더 싫어할 도대체 로미 얘 역할 뭔지 전혀 모르',
#   '7'],
#  ['140693', ' 꽤볼 합 살짝 잔 혹시 가나 올 요 나오면 또볼 의향 있는', '8'],
#  ['140693',
#   ' 만화 영화 단점 벗어 못 했 만화 영화 연출 차이 나오는 오글거림 원작 긴 스토리 반영하지 못 하고 부분 에피소드 영화 한 한계 벗어 못 했 좀비 퀄리티 대단했',
#   '6'],
#  ['140693', ' 잔인 재밌다', '9'],
#  ['140693', ' 피 향연 끝 남는 것 쾌감 아니 허무 함', '5'],
#  ['140693', ' 원작 부족한 점 잘 살리 원작 잘됬 부분 죽 여러 모로 아쉬운 영화 잔인 건 덤', '6'],
#  ['140693', ' 끝나고 말 않 나오네 요하', '1'],
#  ['140693', ' 어여쁜 소녀 좀비 변해 묘 매력 느껴짐', '8'],
#  ['140693', ' 고어 물이 액션 물 좀비 물 급 본 매니아 선 나쁘 않았 재밌었', '9'],
#  ['140693', ' 만화책 보고 봐 잼 안보 봐 봐 잼 그러 헐 재미 짐', '10'],
#  ['140693', ' 개인 부산 행보 재밌었 역시 좀비 총 약간 고어 있어 재밌는 것 같', '10'],
#  ['140693', ' 평점 믿지 마라 최근 한국영 속았 다가 오랜만 잼 영화 보았', '10'],
#  ['140693', ' 대왕 좀비 순위 매겨 봤 위 서울역 위 임 히어로 위 부산 행', '7'],
#  ['140693',
#   ' 아니 이영화 왜 자꾸 부산 행 비교하지 애 간 선 내 평 등록 잘 이영화 그냥 끝 잔인 하게 쏴 죽이는 용이 없어 부산 행 좀비 빠르기 두 초반 여친 좀비 변할 땐 기대했 뒤론 후지산 간다',
#   '1'],
#  ['140693', ' 원작 만화가 진행중 영화 끝 부분 흐지부지 좀비 영화 좋아한 뭐 볼 합', '10'],
#  ['140693', ' 부산 행 좀비 보다 더 좋 만화 요소 있어 현실 감 더 떨어졌', '9'],
#  ['140693',
#   ' 솔직하게 쓰 초반 재밌다 후반 약간 재미 떨어짐 부산 행 재밌긴 했 좀비 영화 특유 맛 떨어지는 이 영화 그런 점 높게 평가됨 외국 상 쓸어 담은 아님 부산 행 잘 뽑힘',
#   '8'],
#  ['140693',
#   ' 결말 없는 좀비 영화 여운 없다 히로 미가 레지던트 이블 주인공 조큔 바이러스 인해 진화 되는 것 기대한 암것 안 여주 인공 대형 마트 겁쟁이 남 주인공 어쩌다 만난 여고생 하나 살리 총 여 마리 좀비 잡고 게임 끝',
#   '3'],
#  ['140693', ' 좀비 볼때 분장 파워 레인 져 악당 보는 듯 느낌', '4'],
#  ['140693',
#   ' 일단 만화 정독 했 장르 마음 들어서 보게 되었 각 케릭 터 개성 잘 살렸 특유 일본 개그 재밌진 않았 실소 머금 하면 알 있는 내용 점점 성장해 주인공 모습 스크린 보니 감회 새로웠',
#   '10'],
#  ['140693',
#   ' 이런 식 확실한 장르 좋 타 우리나라 특징 웃고 애잔하고 울 무섭 넣어 버리니 이도 저 아닌 영화 히어로 처럼 정말 주제 어울리 만들 좀비 물이 이런 영화 보면 사랑 타령 인간 생각하지 마라 그냥 좀비 물이 실음 다른 봐',
#   '9'],
#  ['140693', ' 예고편 썸네일 잔인 걸 하면 어떡하 간 떨어질 뻔', '7'],
#  ['140693', ' 공존 본성 사이 갈등 고뇌 담아', '8'],
#  ['140693', ' 부산 행 감독 이 영화 보고 좀비 어떻 표현해야 하는 좀 배우는 게 좋', '6'],
#  ['140693', ' 좀비 다시 생각하게 만든 영화 좀비 과거 산다 높이뛰기 선수 좀비 왜 부산 행 모티브 알', '10'],
#  ['140693',
#   ' 취향 갈리 보네 좀비 물 본 없는 동양 좀비 물 나와 좋 평점 너 무안 좋 기대 했 전 재밌게 봤 결말 만화 결말 났 이해합',
#   '10'],
#  ['140693',
#   ' 생애 최악 영화 재미있다 본 사람 굉장히 취향 독특하신 재미없 지루하고 주인공 욕 정도 한심하며 원인 결말 없는 밑 끝 없는 그런 영화 임',
#   '1'],
#  ['140693', ' 일본 얘 들 영화 만들 됀 다시 실감 했 영화 만들 돈 애니 만들어', '1'],
#  ['140693', ' 영웅 부각 시키 위한 도구 좀비', '7'],
#  ['140693', ' 잔임함 끝판 부산 생 장난 였', '9'],
#  ['140693', ' 좀비 영화 좋아하는 잔인 괜찮 약간 긴장감 떨어지 주후 부산 행 더 긴장감 있고 좋 것 같아', '5'],
#  ['140693',
#   ' 냉정 하게 말하자 택시 숨도 쉬 그 뒤 루즈 했 히데 오 내적 갈등 두려움 잘 표현되 그럭저럭 재미있게 봤 용감한 근육남 무쌍 찍는 좀비 영화 배는 났',
#   '10'],
#  ['140693',
#   ' 여친 보 자고 보러 갔 헤어질 뻔했 영화 끝나고 집 내내 나 미안하다 했 정말 재미없 영화 였 좀비 분장 끝내 잘했 내용 주인공 샷건 뺏어 내 머리 쏘고',
#   '2'],
#  ['140693', ' 좀비 물 좋아한 강력 추천', '10'],
#  ['140693', ' 대 반전 마지막 짐 된 로미 무능력 돈 벌기 쉽', '8'],
#  ['140693',
#   ' 일본 만화 원작 영화 평 원작 얼마나 충실 가를 말한 그런 점수 높다 다만 만화 연출 조금 리얼리티 입각 관객 몰입도 흐리 된 초반 자인 부분 사람 공포 주전부리 먹지 않다 후반 부 먹으 본',
#   '9'],
#  ['140693', ' 솔직히 점 주신 택시 보고 나온 맞죠', '4'],
#  ['140693', ' 개인 매우 재밌게 봤 무서운 장면 저 모르 섬찟 여주 인공 절반 좀비 도 예쁩', '10'],
#  ['140693', ' 왜 평점 좋 저 로 봤 좀비 영화 조합 괜찮 나쁘 않은 신선한 좀비 영화 입니', '8'],
#  ['140693', ' 일본 특 유의 유머러스함 아직 낮 설 좀비 영화 잔인함 긴장감 잘 살린 같아 재미있게 보았', '8'],
#  ['140693', ' 이런 게 좀비 영화 원작 보러 갑', '10'],
#  ['140693', ' 예고편 낚임 영화 보고 애니 본 느낌', '4'],
#  ['140693', ' 볼 만화책 보세', '1'],
#  ['140693', ' 기 보고 쓰레기통 버리 왔 내용 하나 없 개 찌 남 얘기', '1'],
#  ['140693',
#   ' 스토리 보면 안되 액션 하나 최고 였 초반 여자친구 집 장면 고어 물 좀비 물 어지간히 좋아하는 나도 눈 돌릴 정도 였 좀비 물 로써 최고 였',
#   '8'],
#  ['140693', ' 관왕 한 영화 아니', '9'],
#  ['140693', ' 텟코 텟코 메론빵 사왔 텟코', '8'],
#  ['140693', ' 부산 행 다르 나름 볼 영화', '8'],
#  ['140693', ' 와 진짜 나가서 토할 뻔했 와', '1'],
#  ['140693',
#   ' 급 영화 만화 재밌게 봐 영화 봤 만화 떠나서 진짜 더럽 허 접하다 중간 중간 깜짝 놀란 빼 심심하게 봣 좀비 영화 좋아하지 무서운 걸 보는 아닌 참 심심하게 봄 가능성 보임 만화 영화 가능성',
#   '5'],
#  ['140693', ' 부산 행 비해 재미 지고 리얼 함', '10'],
#  ['140693', ' 스 까 국행 재밌 좀 고어 비위 약하면 볼 싶', '8'],
#  ['140693', ' 평점 처음 남겨 보네 보자 한 친구 물 뻔 했', '1'],
#  ['140693', ' 부산 행보 디 재밌다', '10'],
#  ['140693',
#   ' 평점 적당 잔인 좀비 씨쥐 괜찮 스토리 없고 일본 오타쿠 개그 혀 끌끌 참 엔딩크레딧 올라가고 헛 웃음 면서 나옴 역시 일본 개그 맞는 개연 없는 고어 오타쿠 히어로 물',
#   '1'],
#  ['140693', ' 재밌는 로미 얼굴 마딤', '10'],
#  ['140693', ' 개연 성은 좀 아쉽 전체 긴장감 흡입 합격 점 원작 비교하지 않는 상당히 준수 작품', '8'],
#  ['140693', ' 일본인 오타쿠 감성 대한 거부 감 없는 분 보세', '1'],
#  ['140693', ' 진정 만 찢 남 속편 꼭 나왔 함 부산 후지산 훨났', '8'],
#  ['140693', ' 자고로 좀비 영환 금 딱지 붙이 봐 부산 행보 배 잼 봤', '9'],
#  ['140693', ' 히데 오 최고 플레이', '8'],
#  ['140693', ' 와 이런 기 같은 영화 오랜만 봄 없어 웃긴 상황 깨알 멜로 승화 시킨 감독 박수 때려 부수 싶다', '1'],
#  ['140693', ' 왜 평점 부산 행보 재밌는', '10'],
#  ['140693', ' 왜 됐 이유 없고 그냥 말 안되 진행하네', '3'],
#  ['140693', ' 개인 재미있었 좀비 물 좋아하고 다른 좀비 영화 비교해서 보면 재미있', '8'],
#  ['140693', ' 과장 되 그 속 메세지 있다', '9'],
#  ['140693', ' 난 거 부산 행 낫 좀비 무서웠', '5'],
#  ['140693', ' 봐 야함 흩', '10'],
#  ['140693',
#   ' 평점 영점 없 돈 아까운 쓰레기 영화 스토리 메세지 감동 연결고리 뭣 창자 터지 머리 터지 피떡 칠하고 정신 황폐 해지 영화 일본 한국 안되 보다',
#   '1'],
#  ['140693', ' 역대 쓰레기 영화 도저히 평점 줄 가치 없', '1'],
#  ['140693', ' 히로 미짱', '10'],
#  ['140693', ' 킬링타임 용 돈 아깝 않 좀비 물 좋아한', '9'],
#  ['140693', ' 돈 버리 가지 마세 별 개도 아깝', '1'],
#  ['140693', ' 음 좀비 싸울 때 난 졸음 싸웟 여자친구 싸웟', '1'],
#  ['140693', ' 좀비 영화 최고봉 걸 보고 봤 논할 수 없다', '10'],
#  ['140693',
#   ' 점 대의 평점 받 구린 영화 아니 생각하는 좀비 영화 스토리 기대하고 보는 자체 너무 많은 기대 하다 좀비 묘사 중간 중간 코믹 요소 나름 괜찮 좀비 물 좋아하면 추천',
#   '8'],
#  ['140693',
#   ' 영화 보는 내내 토 나올 것 같고 짜증 나고 건강 해롭 생각 했 좀비 영화로 성공 일진 몰라 다시 일본 공포 영화 안보 렵니',
#   '1'],
#  ['140693',
#   ' 좋 제일 쎄 보이는 로미 왜 암것 안 함 원작 어떨 모르 영화 봤 땐 짐 덩이 그 이상 이하 아님 없는 편이 더 나 것 같아 하드 하기 최고 분장 의 콜라보 대단하네',
#   '3'],
#  ['140693', ' 진짜 기대 봤 짱 재밌었 적당히 통쾌 적당히 좋 결말', '9'],
#  ['140693', ' 좀비 좋아하는 사람 꼭 봐 야할 필수 영화 전 너무 재밌게 봤 책 보려', '9'],
#  ['140693', ' 그냥 유치 일본 만화 잔인 내용 개연 성은 전혀 없고 긴장감 없었', '1'],
#  ['140693', ' 여주 고양이 개 바 였', '6'],
#  ['140693', ' 개 답답하고 잔인 잔인 존나 남 주가 아저씨 같 포켓몬스터 지우 같 좆 노잼 결말 허무', '1'],
#  ['140693',
#   ' 좀비 영화 이래 오랜만 하드코어 좀비 물 본 원작 방대 스토리 심리 묘사 예상했 담아 했 히로 미도 제 역할 했 또 육교 비행기 씬 이우 씬등 원작 주옥 같은 연출 제대로 표현 해낸 아쉬웠',
#   '7'],
#  ['140693', ' 연출 보는 내내 아쉬웠 좀비 대한 표현 좋', '5'],
#  ['140693', ' 노답 솔직히 아쉬운 영화 였', '1'],
#  ['140693', ' 궁금한 사람 봐 보세', '1'],
#  ['140693', ' 인생 최고 쓰레기 영화 드래곤볼 있다 이영화 른 본 시간 기억 지우고 더 이상 인생 일본 영화 없다', '1'],
#  ['140693',
#   ' 진짜 찌 주인공 속 터져 죽는 진짜 개 답답했 좀비 죽길 바라지 않고 주인공 죽었 하고 수백 번 되새 기 한',
#   '1'],
#  ['140693', ' 좀비 특성 참신 하게 잡았 스토리 연출 말 먹음', '3'],
#  ['140693', ' 나 당할 순 없다', '10'],
#  ['140693', ' 댓글 보고 낚였음 시간 아까 움', '1'],
#  ['140693', ' 걸 재밋다 하는 이해 못하겟 좋 댓글 웅 차단 하나 진짜 분장 빼고 돈 아깝 시간 아깝 허무 하다', '1'],
#  ['140693', ' 솔직히 기대 갔 부산 행보 볼 점 이상 줄 영화 생각합 순천 관람객', '9'],
#  ['140693', ' 좀비 보려 가면 괜찮 영화 잔인 것 보는 사람 보면 기분 잡 영화', '1'],
#  ['140693', ' 스트레스 풀 싶 때 영화관 볼 합', '8'],
#  ['140693', ' 부산 행 보고 기대 이하 실망하신 분 이 영화 보시', '9'],
#  ['140693',
#   ' 좀비 참신 고어 함 잔인 거 좋아해서 점 좋 스토리 진짜 없는 느낌 더 웃긴 지금 사귄 여자친구 생각 안나 자기 처음 모르는 미소녀 여고생 겁나 챙김 오타쿠 히어로 되 판타지 떡밥 풀 챙기 않',
#   '5'],
#  ['140693', ' 와 의자 흔들 흔들 부산 행은 무것 도아 엿', '8'],
#  ['140693', ' 부산 행보 재미있었', '10'],
#  ['140693', ' 웬만하면 거 쓰는 아니 거 처음 씁 리뷰 한국 정서 맞는 내용 한마디 씹 노잼', '2'],
#  ['140693', ' 점 영화 아니 꿀잼', '10'],
#  ['140693', ' 아니 왜 로미 무것 도안 하냐 로미 망쳐', '6'],
#  ['140693', ' 점도 아깝', '1'],
#  ['140693', ' 것 영화 학예회 수준', '1'],
#  ['140693', ' 돈 아깝 노잼 차라리 부산 행 나 스토리 없고 그냥 죽 죽이는 별 점도 아까 움', '1'],
#  ['140693', ' 보는 속 편합', '1'],
#  ['140693',
#   ' 영화 내용 전혀 없 그냥 좀비 때려 잡다 끝나고 현실 좀비 나온 이럴 아니 애니매이션 비현실적 요소 너무 많아 주인공 앞 좀비 모기 쉽 죽 개인 너무 별로',
#   '1'],
#  ['140693',
#   ' 솔직히 아시아 좀비 영화 꽤 수작 였 티 전혀 없고 원작 비해 내용 빠진 부분 있었 재미있었 누구 잔 별점 테러 하는 이는 개인 잔인 거 보는 걸 영화 까는 것임 재미있으 꼭 보길 물론 잔인함',
#   '10'],
#  ['140693', ' 진짜 재미있고 부산 행보 스릴 있었 평점 왜 이런', '10'],
#  ['140693',
#   ' 개봉 전 관심 있어 꼭 봐 했 평점 후기 보고 너무 좋 망설였 만화 내용 모르 보자 봤 정말 시간 어떻 지나갔 모를 만큼 몰입 재미있게 봤 편 편 계속 나오길',
#   '9'],
#  ['140693', ' 재밌다 웃음 포인트 있고 시원한 샷건 좋 기대 이상 좀비 물', '9'],
#  ['140693', ' 바람 검 이후 원작 재현 율 정말 재미 나겜', '10'],
#  ['140693', ' 방금 봄 맥락 여고생 고양이 사기 캐 되 그냥 맥락 노잼 핵 노잼', '1'],
#  ['140693', ' 내 인생 최악 영화 탑 들어감 영화 보면 돈 이 아까웠 적 몇번 없다', '1'],
#  ['140693', ' 오랜만 별 거지같 쓰레기 영화 볼 수 있어 뜻 깊은 시간 이었', '1'],
#  ['140693', ' 부산 행 못지않 쓰레기', '2'],
#  ['140693', ' 기 내 아까운 주말 시간 쳐 날림 절대 보지 마세 존나 재미없', '1'],
#  ['140693',
#   ' 이런 좀비 영화 새벽 저주 주후 올 본 좀비 영화 수작 그것 일본 부산 행 비교 채 거부 같은 좀비 영화 장르 채 다름 신파 없고 현실 가득한 좀비 영화',
#   '10'],
#  ['140693', ' 진짜 답 없는 영화 기 대감 가지 보니 실망 감 더크', '1'],
#  ['140693', ' 영화 보면 머리 아프', '1'],
#  ['140693',
#   ' 좀비 영화 포인트 극한 상황 왔 때 나라 어떻 상황 대처할 하는 여자친구 동료 어쩔 죽일 없는 상황 의 표현 약햇으 주인공 성장 나름 마음 드네',
#   '9'],
#  ['140693', ' 억울하다 나 당할 순 없다', '1'],
#  ['140693', ' 원작 바뀌 나름 재밌게 볼 좀비 영화', '7'],
#  ['140693', ' 잔인 노잼 처음 부분 이후 그닥', '1'],
#  ['140693', ' 내용 없고 기억나는 피 머리', '5'],
#  ['140693',
#   ' 좀비 영화 라면 감정 이입 할 현실 있어 야한 생각하는 입장 역대 최악 좀비 영화 였 긴 않겠 입장 주인공 발 쏘고 장전 할 때 기다려 좀비 있다 생각하면 보셔 될 합',
#   '1'],
#  ['140693', ' 현실 주인공 잘 살렸 후속 편도', '7'],
#  ['140693', ' 일본 특유 느낌 나 영화 였 재밌었 보고 나서도 계속 생각나고 또 보고 영화', '8'],
#  ['140693', ' 재미없 유명한 일본 영화 약간 불안 이 영화 이 불안 씹어 드셨 나 로미 씹덕 사 당했', '10'],
#  ['140693',
#   ' 왠만하면 로그인 합 글 안남 기고 초반 부의 약간 흥미 로움 끝 그냥 그로테스크 함 연속 억지 너무 끼어 했 추천할 작품 아닌 같',
#   '3'],
#  ['140693', ' 잔인 살짝 지루함', '7'],
#  ['140693', ' 좀비 터지는 영화', '6'],
#  ['140693', ' 아울렛 옥상 납득 대장 나온 맞', '2'],
#  ['140693', ' 탄도 만들어지 기원 로미 왜', '9'],
#  ['140693', ' 진짜 하드코어 좀비 물 상영 관 너무 없네', '10'],
#  ['140693',
#   ' 초반 전개 그 어떤 영화 무서웠 중간 살짝 지루 막판 짜릿했 왜 이영화 평점 낮은 모르 생각 넘 재미있었 관람객',
#   '9'],
#  ['140693', ' 재미있 추천함 역시 좀비 물 금 딱지 달 시작해야', '9'],
#  ['140693',
#   ' 개도 아깝 영화 보는 지루하고 짜증 나더 원래 고어영화 좋아해서 보러 갔 용도 너무 류 주인공 작자 답답하다 차라리 죽었 좋 생각함 다신 평점 알바 말 믿는 영화 보는 시간 가긴 처음',
#   '1'],
#  ['140693', ' 역시 좀비 터뜨려 제맛', '10'],
#  ['140693', ' 돈 아깝 않고 나름 괜찮 영화 시간 때문 칼질 좀 게 아까웠', '8'],
#  ['140693', ' 이용철 재미없 했 고로 재미있 것', '8'],
#  ['140693', ' 평점 조작 이쯤 하면 됐 알바', '1'],
#  ['140693', ' 좀비 매니아 로써 동양 의 좀비 어색하지 않게 잘 표현하였 용이 따라가네 노잼', '1'],
#  ['140693', ' 돈 아까웠 재밌는 평점 왜 이럼', '10'],
#  ['140693', ' 총기 허가 등록 받고 엽총 소지 해야 하나 생각 드는 영화 였', '10'],
#  ['140693', ' 거 상영 관좀 늘려 아아 아아', '10'],
#  ['140693',
#   ' 세라 그런 좀비 퀄 잔인함 정도 상당했 좀비 영화 좋아하는 나로 선 만족스러운 연출 이었 그것 스토리 부산 행 별로 였 만화책 볼땐 재밌다 들 하는 영화 잘 모르 그냥 잔인 사격 물 본 기분',
#   '4'],
#  ['140693', ' 볼 했 부산 행', '6'],
#  ['140693',
#   ' 좀비 의 퀄리티 상당했 물 뜯고 쏘고 하는 액션 최고 였 청 불로 만들어져 비로소 제대로 즐길 있는 장르 란 것 느낄 수 있',
#   '10'],
#  ...]

# %%
docs1 = [doc[1].strip().split() for doc in docs]

# %%
model = Word2Vec(docs1, window=3, min_count=3, size=100)

# %%
model.wv.similar_by_word(u'이정재',topn=20)
# Out:
# [('이범수', 0.7803266048431396),
#  ('김윤석', 0.75974440574646),
#  ('공유', 0.7361782789230347),
#  ('송강호', 0.7165535688400269),
#  ('조재현', 0.7124308347702026),
#  ('이성민', 0.7075873613357544),
#  ('김범수', 0.6944841146469116),
#  ('주지훈', 0.6861358880996704),
#  ('김남길', 0.6848186254501343),
#  ('이진욱', 0.6803741455078125),
#  ('박해일', 0.6692052483558655),
#  ('하정우', 0.66161048412323),
#  ('이병헌', 0.6599633693695068),
#  ('요한', 0.6575193405151367),
#  ('정우성', 0.6537964344024658),
#  ('곽도원', 0.6426882147789001),
#  ('마동석', 0.642478346824646),
#  ('김성오', 0.6387029886245728),
#  ('조진웅', 0.6352361440658569),
#  ('김명민', 0.6289377212524414)]

# %%
model

# %%
import numpy as np
from scipy import spatial

index2word_set = set(model.wv.index2word)

def avg_feature_vector(sentence, model, num_features, index2word_set):
    words = sentence.split()
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_words = 0
    for word in words:
        if word in index2word_set:
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# %%
s1_afv = avg_feature_vector('this is a sentence', model=model, num_features=300, index2word_set=index2word_set)
s2_afv = avg_feature_vector('this is also sentence', model=model, num_features=300, index2word_set=index2word_set)

# %%
sim = 1 - spatial.distance.cosine(s1_afv, s2_afv)
print(sim)
# Out:
# nan
# /anaconda3/lib/python3.6/site-packages/scipy/spatial/distance.py:698: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
import gensim
